# %%
import numpy as np
import matplotlib.pyplot as plt
import hashlib
from copy import deepcopy
from mpl_toolkits.mplot3d import Axes3D
#from qiskit.circuit.library import efficient_su2
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import Statevector
from scipy.optimize import minimize
from scipy.spatial.distance import pdist, squareform
import numpy as np
from qiskit import transpile , QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator

# ==========================================
# 1. UTILITY: TRACKING & LOGGING
# ==========================================
class LandscapeTracker:
    def __init__(self):
        self.history = []
        self.stage_markers = []
        self.current_iter = 0

    def log(self, energy):
        self.history.append(energy)
        self.current_iter += 1

    def mark_stage(self, name):
        self.stage_markers.append((self.current_iter, name))

# ==========================================
# 2. ANALYSIS: STABILITY & CONVERGENCE (KABSCH)
# ==========================================
class StabilityAnalyzer:
    """
    Tools to evaluate if the folding results are structurally consistent.
    Implements the Kabsch algorithm for optimal superposition.
    """
    
    @staticmethod
    def kabsch_rmsd(P, Q):
        """
        Calculates the RMSD between two sets of coordinates P and Q
        after optimally rotating P to align with Q.
        P and Q must be (N, 3) matrices.
        """
        # 1. Centering
        P_centered = P - np.mean(P, axis=0)
        Q_centered = Q - np.mean(Q, axis=0)
        
        # 2. Covariance Matrix
        H = np.dot(P_centered.T, Q_centered)
        
        # 3. SVD
        V, S, Wt = np.linalg.svd(H)
        
        # 4. Rotation Matrix
        d = (np.linalg.det(V) * np.linalg.det(Wt)) < 0.0
        if d: 
            S[-1] = -S[-1]
            V[:, -1] = -V[:, -1]
        
        R = np.dot(V, Wt)
        
        # 5. Rotate and Diff
        P_rotated = np.dot(P_centered, R)
        diff = P_rotated - Q_centered
        rms = np.sqrt(np.mean(np.sum(diff**2, axis=1)))
        
        return rms, P_rotated + np.mean(Q, axis=0) # Return RMSD and Aligned Coords

    @staticmethod
    def analyze_convergence(results, top_k=5):
        """
        Calculates pairwise RMSD between the top K lowest energy structures.
        """
        # Sort by Energy (lowest first)
        sorted_results = sorted(results, key=lambda x: x['energy'])
        best_k = sorted_results[:top_k]
        n = len(best_k)
        
        if n < 2: return
        
        print(f"\n--- CONVERGENCE ANALYSIS (Top {n} Structures) ---")
        
        rmsd_matrix = np.zeros((n, n))
        
        # Print Header
        print("      ", end="")
        for i in range(n): print(f" #{i:<4}", end="")
        print("\n" + "-"*60)
        
        for i in range(n):
            print(f"Ref #{i} |", end="")
            for j in range(n):
                if i == j:
                    rmsd_matrix[i, j] = 0.0
                else:
                    # Note: Using all atoms for RMSD. Ideally filter for 'CA' only.
                    rmsd, _ = StabilityAnalyzer.kabsch_rmsd(best_k[i]['coords'], best_k[j]['coords'])
                    rmsd_matrix[i, j] = rmsd
                
                print(f" {rmsd_matrix[i, j]:.2f} ", end="")
            print(f"  (E={best_k[i]['energy']:.1f})")
            
        avg_rmsd = np.sum(rmsd_matrix) / (n*(n-1))
        print(f"\nAverage Pairwise RMSD: {avg_rmsd:.2f} Angstroms")
        
        if avg_rmsd < 2.0:
            print(">>> VERDICT: STABLE. High confidence in prediction.")
        elif avg_rmsd < 4.5:
            print(">>> VERDICT: FLEXIBLE. Core is stable, loops vary.")
        else:
            print(">>> VERDICT: UNSTABLE. No dominant basin found.")

# ==========================================
# 3. CORE: QUANTUM FOLDER
# ==========================================
class QuantumBiophysicsFolder:
    """
    A Hybrid Quantum-Classical Protein Folder.
    
    ARCHITECTURE:
    1. Quantum Actor (The Generator): 
       Uses a parameterized quantum circuit (VQE ansatz) to generate a probability distribution.
       These probabilities are mapped to physical torsion angles (phi, psi, chi).
       
    2. Classical Critic (The Energy Function):
       Constructs the 3D geometry from those angles and evaluates its physical stability
       using a custom force field (hydrophobicity, electrostatics, H-bonds, etc.).
       
    3. Optimization Loop:
       Classical optimizers (COBYLA/SLSQP) tune the quantum circuit parameters to minimize the energy.

    REFERENCES:
    1. Hydrophobicity: Kyte, J., & Doolittle, R. F. (1982). A simple method for displaying the hydropathic character of a protein.
    2. Electrostatics: CHARMM22 / OPLS-AA Force Fields (Approximated partial charges).
    3. VdW Radii: Bondi, A. (1964). Van der Waals volumes and radii.
    4. Topology: Engh, R. A., & Huber, R. (1991). Accurate bond and angle parameters for X-ray protein structure refinement.
    5. Heuristics: Manual tuning ("Quantum Velcro") for folding convergence.
    """

    def __init__(self, sequence, force_field='charmm'):
        """
        Initialize the folder.
        
        Args:
            sequence (str): Amino acid sequence (e.g., 'MAG').
            force_field (str): 'charmm', 'amber', or 'opls'. Determines partial charges.
        """
        self.sequence = sequence.upper()
        self.n_residues = len(sequence)
        self.force_field = force_field.lower()
        
        print(f"--- INITIALIZING QUANTUM BIOPHYSICS FOLDER ---")
        print(f"--- FORCE FIELD: {self.force_field.upper()} ---")
        
        # --- PARAMETERS (Force Field Constants) ---

        # 1. HYDROPHOBICITY SCALE
        # Ref: Kyte, J., & Doolittle, R. F. (1982). J. Mol. Biol. 157, 105-132.
        self.HYDROPHOBICITY = {
            'I': 4.5, 'V': 4.2, 'L': 3.8, 'F': 2.8, 'C': 2.5,
            'M': 1.9, 'A': 1.8, 'G': -0.4, 'T': -0.7, 'S': -0.8,
            'W': -0.9, 'Y': -1.3, 'P': -1.6, 'H': -3.2, 'E': -3.5,
            'Q': -3.5, 'D': -3.5, 'N': -3.5, 'K': -3.9, 'R': -4.5
        }
        
        # 2. PARTIAL CHARGES (Coulomb's Law)
        # We now support switching between major force field approximations.
        # While coarse-grained, these capture the distinct dipole strengths of each FF.
        
        # BASE (Shared Ions)
        common_charges = {
            'OXT': -1.0, 
            'NZ': 1.0, 'NH1': 0.5, 'NH2': 0.5, 
            'OD1': -0.5, 'OD2': -0.5, 'OE1': -0.5, 'OE2': -0.5,
            'ND2': 0.5, 'NE2': 0.5, 
            'SG': -0.1, 'SD': -0.1,
            'HE2': 0.4, 'ND1': -0.4, # His
        }

        # CHARMM22 (The original default)
        # Strong dipoles, balanced C-alpha.
        charmm_charges = {
            'N': -0.47, 'H': 0.31, 'CA': 0.07, 'C': 0.51, 'O': -0.51,
            'OG': -0.4, 'HG': 0.4, 'OG1': -0.4, 'HG1': 0.4, 'OH': -0.4, 'HH': 0.4,
            'NE1': -0.3, 'HE1': 0.3
        }
        
        # AMBER (ff94/99/14SB approx)
        # N is slightly less negative, C=O is very polar. C-alpha is often neutral.
        amber_charges = {
            'N': -0.42, 'H': 0.27, 'CA': 0.00, 'C': 0.60, 'O': -0.57,
            'OG': -0.6, 'HG': 0.4, 'OG1': -0.6, 'HG1': 0.4, 'OH': -0.5, 'HH': 0.4, # Ambient hydroxyls often stronger
            'NE1': -0.4, 'HE1': 0.3
        }

        # OPLS-AA
        # Very standardized backbone dipoles (+0.5/-0.5).
        opls_charges = {
            'N': -0.50, 'H': 0.30, 'CA': 0.14, 'C': 0.50, 'O': -0.50,
            'OG': -0.7, 'HG': 0.4, 'OG1': -0.7, 'HG1': 0.4, 'OH': -0.7, 'HH': 0.4,
            'NE1': -0.4, 'HE1': 0.35
        }

        # Select Strategy
        self.CHARGES = common_charges.copy()
        if self.force_field == 'amber':
            self.CHARGES.update(amber_charges)
        elif self.force_field == 'opls':
            self.CHARGES.update(opls_charges)
        else: # Default to CHARMM
            if self.force_field != 'charmm':
                print(f" > Warning: Unknown force field '{self.force_field}'. Defaulting to CHARMM.")
            self.CHARGES.update(charmm_charges)
        
        # 3. VAN DER WAALS RADII (Angstroms)
        # Ref: Bondi, A. (1964). J. Phys. Chem. 68, 441-451.
        self.VDW_RADII = {'H': 0.6, 'C': 1.7, 'N': 1.55, 'O': 1.52, 'S': 1.8}
        
        # 4. SIDE CHAIN TOPOLOGY
        # Ref: Engh, R. A., & Huber, R. (1991). Acta Cryst. A47, 392-400.
        self.SIDE_CHAIN_TOPO = {
            'G': [],
            'A': [('CB', 'CA', 1.53, 1.91, 2.1)],
            
            # Hydrophobic
            'V': [('CB', 'CA', 1.53, 1.91, 'chi1'), 
                  ('CG1', 'CB', 1.52, 1.91, 'chi2'), ('CG2', 'CB', 1.52, 1.91, 'chi2_branch')],
            'L': [('CB', 'CA', 1.53, 1.91, 'chi1'), 
                  ('CG', 'CB', 1.52, 1.91, 'chi2'), 
                  ('CD1', 'CG', 1.52, 1.91, 'chi3'), ('CD2', 'CG', 1.52, 1.91, 'chi3_branch')],
            'I': [('CB', 'CA', 1.53, 1.91, 'chi1'), 
                  ('CG1', 'CB', 1.54, 1.91, 'chi2'), ('CD1', 'CG1', 1.52, 1.91, 'chi3'),
                  ('CG2', 'CB', 1.54, 1.91, 'chi2_branch')],
            'M': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('SD', 'CG', 1.81, 1.91, 'chi3'), ('CE', 'SD', 1.79, 1.76, 'chi4')],
            'P': [('CB', 'CA', 1.53, 1.80, 'chi1'), ('CG', 'CB', 1.50, 1.82, 'chi2'),
                  ('CD', 'CG', 1.52, 1.83, 'chi3')], 

            # Aromatic
            'F': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.50, 1.91, 'chi2'),
                  ('CD1', 'CG', 1.39, 2.09, 1.57), ('CD2', 'CG', 1.39, 2.09, -1.57),
                  ('CE1', 'CD1', 1.39, 2.09, 3.14), ('CE2', 'CD2', 1.39, 2.09, 3.14),
                  ('CZ', 'CE1', 1.39, 2.09, 0.0)],
            'Y': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.50, 1.91, 'chi2'),
                  ('CD1', 'CG', 1.39, 2.09, 1.57), ('CD2', 'CG', 1.39, 2.09, -1.57),
                  ('CE1', 'CD1', 1.39, 2.09, 3.14), ('CE2', 'CD2', 1.39, 2.09, 3.14),
                  ('CZ', 'CE1', 1.39, 2.09, 0.0), 
                  ('OH', 'CZ', 1.37, 2.09, 3.14), ('HH', 'OH', 0.96, 1.83, 'chi3')], 
            'W': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.50, 1.91, 'chi2'),
                  ('CD1', 'CG', 1.37, 2.15, 1.0), ('CD2', 'CG', 1.43, 2.15, -1.0),
                  ('NE1', 'CD1', 1.38, 1.90, 3.14), ('HE1', 'NE1', 1.01, 2.09, 0.0), 
                  ('CE2', 'CD2', 1.40, 1.90, 0.0), ('CE3', 'CD2', 1.40, 2.30, 3.14), 
                  ('CZ2', 'CE2', 1.40, 2.10, 0.0), ('CZ3', 'CE3', 1.40, 2.10, 0.0), 
                  ('CH2', 'CZ2', 1.40, 2.10, 0.0)], 

            # Polar / Charged
            'S': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('OG', 'CB', 1.42, 1.91, 'chi2'),
                  ('HG', 'OG', 0.96, 1.83, 'chi3')], 
            'T': [('CB', 'CA', 1.53, 1.91, 'chi1'), 
                  ('OG1', 'CB', 1.43, 1.91, 'chi2'), ('HG1', 'OG1', 0.96, 1.83, 'chi3'), 
                  ('CG2', 'CB', 1.53, 1.91, 'chi2_branch')],
            'C': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('SG', 'CB', 1.81, 1.91, 'chi2')],
            'D': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('OD1', 'CG', 1.25, 2.0, 1.0), ('OD2', 'CG', 1.25, 2.0, -1.0)],
            'N': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('OD1', 'CG', 1.23, 2.09, 0.0), ('ND2', 'CG', 1.32, 2.09, 3.14)],
            'E': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('CD', 'CG', 1.52, 1.91, 'chi3'), ('OE1', 'CD', 1.25, 2.0, 1.0), ('OE2', 'CD', 1.25, 2.0, -1.0)],
            'Q': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('CD', 'CG', 1.52, 1.91, 'chi3'), ('OE1', 'CD', 1.23, 2.09, 0.0), ('NE2', 'CD', 1.32, 2.09, 3.14)],
            'K': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('CD', 'CG', 1.52, 1.91, 'chi3'), ('CE', 'CD', 1.52, 1.91, 'chi4'),
                  ('NZ', 'CE', 1.49, 1.91, 'chi5')],
            'R': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('CD', 'CG', 1.52, 1.91, 'chi3'), ('NE', 'CD', 1.46, 1.91, 'chi4'),
                  ('CZ', 'NE', 1.33, 2.15, 'chi5'), ('NH1', 'CZ', 1.33, 2.10, 0.0), ('NH2', 'CZ', 1.33, 2.10, 3.14)],
            'H': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.50, 1.91, 'chi2'),
                  ('ND1', 'CG', 1.38, 2.15, 1.0), ('CD2', 'CG', 1.36, 2.15, -1.0),
                  ('CE1', 'ND1', 1.32, 1.90, 0.0), 
                  ('NE2', 'CD2', 1.32, 1.90, 0.0), ('HE2', 'NE2', 1.01, 2.09, 0.0)], 
            
            'DEFAULT': [('CB', 'CA', 1.53, 1.91, 'chi1')]
        }

        # --- QUANTUM SETUP ---
        # 1. Map sequence to Degrees of Freedom (DoF)
        self.dof_map = []
        for i, aa in enumerate(self.sequence):
            self.dof_map.append({'res': i, 'type': 'phi'}) # Backbone torsion
            self.dof_map.append({'res': i, 'type': 'psi'}) # Backbone torsion
            
            # Add Sidechain torsions (chi)
            topo = self.SIDE_CHAIN_TOPO.get(aa, self.SIDE_CHAIN_TOPO['DEFAULT'])
            chis = set()
            for atom in topo:
                tor = atom[4]
                if isinstance(tor, str) and 'chi' in tor: chis.add(tor)
            for k in sorted(chis): self.dof_map.append({'res': i, 'type': k})
        
        self.total_angles = len(self.dof_map)
        
        # 2. Holographic Encoding
        # We only need log2(N) qubits to represent N angles in terms of statevector capacity.
        # This makes the algorithm scalable.
        self.n_qubits = max(2, int(np.ceil(np.log2(self.total_angles))))
        
        # 3. The Ansatz (The "Actor")
        # 'efficient_su2' is a heuristic circuit often used in VQE.
        # 'reps' controls depth. More reps = more expressive = harder to train.
        self.reps = int(np.ceil(self.total_angles / self.n_qubits)) + 2
        #self.ansatz = efficient_su2(self.n_qubits, reps=self.reps, entanglement='circular')
        self.ansatz = EfficientSU2(self.n_qubits,reps=self.reps, entanglement='circular')
        self.n_params = self.ansatz.num_parameters
        # --- DEBUG: inspect ansatz parameters ---
        print("\n--- ANSATZ INFO ---")
        print("n_qubits:", self.n_qubits)
        print("reps:", self.reps)
        print("n_params:", self.n_params)
        ans_params = list(self.ansatz.parameters)
        #print("First 10 ansatz parameter symbols:", ans_params[:10])
        
        self.current_stage = 1
        
        # --- PRE-COMPUTE CACHE (Optimization) ---
        # We run the structure builder once with dummy data to figure out which atom is which.
        # This lets us optimize the energy function using Vectorization (NumPy) instead of slow loops.
        self._cache_initialized = False
        self._initialize_topology_cache()
        self.tracker = None  # TRACKER REFERENCE
    
    #def _get_angles(self, params):

        """
        THE HOLOGRAPHIC MAPPING
        Maps Circuit Parameters (Theta) -> Torsion Angles (Phi/Psi/Chi).
        
        Logic:
        1. Assign parameters to the quantum circuit.
        2. Calculate the Statevector (Full wavefunction).
        3. Extract the 'Angle' (phase) of the complex amplitudes.
        4. Use the first N phases as our N torsion angles.
        
        param_dict = dict(zip(self.ansatz.parameters, params))
        bound_circuit = self.ansatz.assign_parameters(param_dict)
        psi = Statevector(bound_circuit).data # Get complex amplitudes
        return np.angle(psi)[:self.total_angles] # Extract phases
        """
    def _get_angles(self, params, backend=None, shots=4096):
        """
        Hardware-compatible torsion extraction:
        (measurement counts) -> (expectations/correlations) -> (torsion angles)

        Key ideas:
        - Measure in multiple bases (Z, X, Y) to get richer features without statevector phases.
        - Use sparse pair correlations (nearest neighbors) to add more signal.
        - Decode per-qubit angles using Bloch-sphere style mapping:
            phi_i = atan2(<Y_i>, <X_i>)
            theta_i = arccos(clip(<Z_i>))
        then use correlations to create extra "psi-like" angles.
        - Finally, deterministically expand/compress to self.total_angles.
        """

        # ----------------------------
        # 0) Backend default
        # ----------------------------
        if backend is None:
            backend = AerSimulator()  # local simulator; replace with IBM backend for real hardware

        # ----------------------------
        # 1) Bind parameters to ansatz
        # ----------------------------
        param_dict = dict(zip(self.ansatz.parameters, params))
        base_qc = self.ansatz.assign_parameters(param_dict)

        n = self.n_qubits  # number of system qubits in ansatz

        # ----------------------------
        # Helpers
        # ----------------------------
        def _measured_in_basis(qc, basis: str):
            """
            Return a NEW circuit that measures all qubits in the given basis.
            basis: 'Z', 'X', or 'Y'
            """
            c = qc.copy()

            # Ensure classical bits exist (measure_all adds them if needed)
            # Apply basis change before measuring:
            if basis.upper() == "X":
                # Measure X by H then measure Z
                for q in range(n):
                    c.h(q)
            elif basis.upper() == "Y":
                # Measure Y by Sdg then H then measure Z
                for q in range(n):
                    c.sdg(q)
                    c.h(q)
            elif basis.upper() == "Z":
                pass
            else:
                raise ValueError("basis must be one of {'Z','X','Y'}")

            c.measure_all()
            return c

        def _run_counts(qc):
            tqc = transpile(qc, backend)
            job = backend.run(tqc, shots=shots)
            result = job.result()
            return result.get_counts()

        def _bit_to_pm1(bit_char: str) -> int:
            # Qiskit: '0' -> +1 eigenvalue, '1' -> -1 eigenvalue (Pauli Z convention)
            return +1 if bit_char == "0" else -1

        def _expectations_from_counts(counts):
            """
            From counts over n bits, compute:
            - single expectations: <b_i> where b_i ∈ {+1,-1}
            - nearest-neighbor correlations: <b_i b_{i+1}>

            Important: Qiskit count keys are returned as strings with classical bit order.
            When using measure_all(), the rightmost character typically corresponds to qubit 0.
            We reverse the string so index i aligns with qubit i.
            """
            total = 0
            single = np.zeros(n, dtype=float)
            pair = np.zeros(max(n - 1, 0), dtype=float)

            for bitstring, c in counts.items():
                p = c / shots
                total += p

                bs = bitstring.replace(" ", "")[::-1]  # reverse so bs[i] matches qubit i
                # Safety if some backends include fewer bits (rare), pad with zeros:
                if len(bs) < n:
                    bs = bs + ("0" * (n - len(bs)))

                zvals = np.array([_bit_to_pm1(bs[i]) for i in range(n)], dtype=float)

                single += p * zvals
                if n >= 2:
                    pair += p * (zvals[:-1] * zvals[1:])

            # total should be ~1.0
            if total > 0:
                single /= total
                if n >= 2:
                    pair /= total

            return single, pair

        # ----------------------------
        # 2) Run circuits in Z/X/Y bases
        # ----------------------------
        counts_Z = _run_counts(_measured_in_basis(base_qc, "Z"))
        counts_X = _run_counts(_measured_in_basis(base_qc, "X"))
        counts_Y = _run_counts(_measured_in_basis(base_qc, "Y"))

        Z, ZZ = _expectations_from_counts(counts_Z)  # Z_i and Z_i Z_{i+1}
        X, XX = _expectations_from_counts(counts_X)  # X_i and X_i X_{i+1} (after basis map)
        Y, YY = _expectations_from_counts(counts_Y)  # Y_i and Y_i Y_{i+1}

        # ----------------------------
        # 3) Decode "primary" angles per qubit from Bloch components
        # ----------------------------
        # phi_i from atan2(Y, X) in [-pi, pi]
        phi = np.arctan2(Y, X)

        # theta_i from arccos(Z) in [0, pi]
        Zc = np.clip(Z, -1.0, 1.0)
        theta = np.arccos(Zc)

        # ----------------------------
        # 4) Make extra "psi-like" angles from correlations
        #    (Use a stable mapping: arccos(correlation) in [0, pi], then shift to [-pi, pi] if desired)
        # ----------------------------
        angles_list = []
        angles_list.extend(phi.tolist())        # n angles
        angles_list.extend((theta - np.pi/2).tolist())  # n angles centered around 0

        # Correlation-based angles
        if n >= 2:
            # Use Z-correlations primarily (like backbone coupling), plus a little XX/YY signal
            corr = 0.5 * ZZ + 0.25 * XX + 0.25 * YY
            corr = np.clip(corr, -1.0, 1.0)
            psi_like = np.arccos(corr) - np.pi/2  # center around 0
            angles_list.extend(psi_like.tolist())  # (n-1) angles

        base_angles = np.array(angles_list, dtype=float)

        # ----------------------------
        # 5) Expand / compress deterministically to self.total_angles
        #    IMPORTANT: base_angles length is O(n), but total_angles can be larger.
        #    We create additional angles via deterministic mixing (no randomness).
        # ----------------------------
        if len(base_angles) == 0:
            base_angles = np.zeros(1, dtype=float)

        if len(base_angles) >= self.total_angles:
            return base_angles[: self.total_angles]

        # Deterministic expansion using a simple sinusoidal mixing bank.
        # This keeps outputs bounded in [-pi, pi] and gives each torsion a distinct value.
        out = np.zeros(self.total_angles, dtype=float)
        out[: len(base_angles)] = base_angles

        # Fill the rest by mixing base angles in a structured way
        L = len(base_angles)
        for k in range(L, self.total_angles):
            i = k % L
            j = (k * 3 + 1) % L
            m = (k * 7 + 2) % L

            v = (
                0.60 * base_angles[i]
                + 0.30 * np.sin(base_angles[j])
                + 0.10 * np.cos(base_angles[m])
            )
            # Wrap to [-pi, pi]
            v = (v + np.pi) % (2 * np.pi) - np.pi
            out[k] = v

        return out
    
    def _nerf_step(self, a, b, c, bond_len, bond_angle, torsion):
        """
        Natural Extension Reference Frame (NERF)
        This is the standard math for placing atom D given atoms A, B, C.
        
        Inputs:
        - a, b, c: Coordinates of previous 3 atoms.
        - bond_len: Distance c -> d
        - bond_angle: Angle b-c-d
        - torsion: Dihedral angle a-b-c-d
        """
        bc = c - b; bc_u = bc / (np.linalg.norm(bc) + 1e-9)
        ab = b - a; n = np.cross(ab, bc_u); n_u = n / (np.linalg.norm(n) + 1e-9)
        bx_n = np.cross(n_u, bc_u)
        
        # Construct rotation matrix column-wise
        M = np.column_stack((bc_u, bx_n, n_u))
        
        theta_supp = np.pi - bond_angle
        d = np.array([bond_len * np.cos(theta_supp), bond_len * np.cos(torsion) * np.sin(theta_supp), bond_len * np.sin(torsion) * np.sin(theta_supp)])
        
        return c + (M @ d)

    def build_full_structure(self, angle_vector):
        """
        Constructs the full 3D Cartesian coordinates of the protein 
        based on the input torsion angles.
        """
        coords = []; labels = []; bonds = [] 
        
        # Map flat angle vector back to semantic names (e.g., '0_phi', '0_psi')
        angle_dict = {f"{x['res']}_{x['type']}": val for x, val in zip(self.dof_map, angle_vector)}
        
        # --- 1. INITIALIZE BACKBONE START ---
        # First 3 atoms (N, CA, C) are placed statically to establish a frame of reference.
        coords.extend([np.array([0,0,0]), np.array([1.46,0,0]), np.array([1.46 + 1.51*np.cos(1.9), 1.51*np.sin(1.9), 0])])
        labels.extend([(0, 'N', 'N'), (0, 'CA', 'C'), (0, 'C', 'C')])
        bonds.extend([(0,1), (1,2)]) 
        
        # --- 2. MAIN RESIDUE LOOP ---
        for i in range(self.n_residues):
            
            # Helper to find index of atoms in the 'coords' list
            def get_idx(r, n):
                for k in range(len(labels)-1, -1, -1): 
                    if labels[k][0] == r and labels[k][1] == n: return k
                return -1

            idx_N = get_idx(i, 'N'); idx_CA = get_idx(i, 'CA'); idx_C = get_idx(i, 'C')
            
            # --- BUILD SIDE CHAIN ---
            topo = self.SIDE_CHAIN_TOPO.get(self.sequence[i], self.SIDE_CHAIN_TOPO['DEFAULT'])
            sc_map = {} 
            for atom_def in topo:
                name, elem, b_len, b_ang, tor_def = atom_def
                
                # Determine Torsion Value
                t_val = 0.0
                if isinstance(tor_def, str) and 'chi' in tor_def:
                    t_val = angle_dict.get(f"{i}_{tor_def.replace('_branch','')}", 0.0)
                    if 'branch' in tor_def: t_val += 2.09 # Offset for branched chains (Val/Leu)
                else: t_val = tor_def # Fixed angle

                # Special Case: First Sidechain Atom (CB) connects to CA
                # Requires calculating the bisector of N-CA-C to place it correctly.
                if name == 'CB': 
                    u_nc = coords[idx_N] - coords[idx_CA]; u_cc = coords[idx_C] - coords[idx_CA]
                    n_plane = np.cross(u_nc, u_cc); n_plane /= (np.linalg.norm(n_plane)+1e-9)
                    u_mid = -(u_nc + u_cc); u_mid /= (np.linalg.norm(u_mid)+1e-9)
                    p_CB = coords[idx_CA] + (b_len * (np.cos(0.9)*u_mid + np.sin(0.9)*n_plane))
                    coords.append(p_CB); labels.append((i, name, elem)); bonds.append((idx_CA, len(coords)-1))
                    sc_map['CB'] = len(coords) - 1
                else:
                    # General NERF placement for rest of sidechain
                    p_name = 'CB'
                    # Determine Parent (Simple logic for standard topologies)
                    if name.startswith('CD'): p_name = 'CG'
                    if name.startswith('CE'): p_name = 'CD'
                    if name.startswith('CZ'): p_name = 'CE'
                    if name.startswith('NZ'): p_name = 'CE'
                    if name.startswith('OE') or name.startswith('OD'): p_name = 'CD' if name.startswith('OE') else 'CG'
                    if name.startswith('SG'): p_name = 'CB'
                    if name.startswith('CG'): p_name = 'CB'
                    if name.startswith('CD') and self.sequence[i] == 'L': p_name = 'CG'
                    
                    # New Parent Mappings for Explicit Hydrogens
                    if name.startswith('HG') and name != 'HG1': p_name = 'OG'
                    if name == 'HG1': p_name = 'OG1'
                    if name == 'HH': p_name = 'OH'
                    if name == 'HE1': p_name = 'NE1'
                    if name == 'HE2': p_name = 'NE2'

                    idx_c = sc_map.get(p_name, -1)
                    if idx_c == -1: idx_c = len(coords) - 1
                    c = coords[idx_c]
                    
                    grandp = 'CA' if p_name == 'CB' else 'CB'
                    # More specific Grandparent mapping for Hydrogens to ensure correct angle
                    if p_name == 'OG': grandp = 'CB'
                    if p_name == 'OG1': grandp = 'CB'
                    if p_name == 'OH': grandp = 'CZ'
                    if p_name == 'NE1': grandp = 'CD1'
                    if p_name == 'NE2': grandp = 'CD2' # For His

                    if grandp == 'CA': b = coords[idx_CA]; a = coords[idx_N]
                    else: b = coords[sc_map.get(grandp, idx_c-1)]; a = coords[idx_CA]
                    
                    new_pos = self._nerf_step(a, b, c, b_len, b_ang, t_val)
                    coords.append(new_pos); labels.append((i, name, elem)); bonds.append((idx_c, len(coords)-1))
                    sc_map[name] = len(coords) - 1

            # --- BUILD BACKBONE OXYGEN (Carbonyl) ---
            p_O = self._nerf_step(coords[idx_N], coords[idx_CA], coords[idx_C], 1.23, 2.1, np.pi) 
            coords.append(p_O); labels.append((i, 'O', 'O')); bonds.append((idx_C, len(coords)-1))
            
            # --- BUILD NEXT RESIDUE BACKBONE (N, CA, C) ---
            if i < self.n_residues - 1:
                psi = angle_dict.get(f"{i}_psi", -0.5)
                p_next_N = self._nerf_step(coords[idx_N], coords[idx_CA], coords[idx_C], 1.33, 2.0, psi)
                coords.append(p_next_N); labels.append((i+1, 'N', 'N')); bonds.append((idx_C, len(coords)-1))
                
                omega = np.pi # Peptide bond is planar (trans)
                p_next_CA = self._nerf_step(coords[idx_CA], coords[idx_C], p_next_N, 1.46, 2.1, omega)
                coords.append(p_next_CA); labels.append((i+1, 'CA', 'C')); bonds.append((len(coords)-2, len(coords)-1))
                
                phi = angle_dict.get(f"{i+1}_phi", -1.0)
                p_next_C = self._nerf_step(coords[idx_C], p_next_N, p_next_CA, 1.51, 1.9, phi)
                coords.append(p_next_C); labels.append((i+1, 'C', 'C')); bonds.append((len(coords)-2, len(coords)-1))

        return np.array(coords), labels, bonds

    def _initialize_topology_cache(self):
        """
        Runs structure builder once to determine static properties of atoms.
        Allows vectorization of Charges, Radii, and Types.
        """
        # Build with dummy zeros to get lists
        dummy_coords, self.static_labels, _ = self.build_full_structure(np.zeros(self.total_angles))
        n_atoms = len(dummy_coords)
        
        # 1. Map Atom Index -> Residue Index
        self.atom_to_res = np.array([x[0] for x in self.static_labels], dtype=int)
        self.atom_names = np.array([x[1] for x in self.static_labels])
        self.atom_elems = np.array([x[2] for x in self.static_labels])
        
        # 2. Pre-calculate Charges (Vectorized)
        self.q_vector = np.zeros(n_atoms)
        for k, (rid, name, elem) in enumerate(self.static_labels):
            q = self.CHARGES.get(name, 0.0)
            res_name = self.sequence[rid]
            
            # --- LOGIC PATCH: RESOLVE CHARGE NAME COLLISIONS ---
            # NE2 is ambiguous: It is an Amide (+0.5) in Gln, but an Amine (-0.4) in Neutral His.
            if res_name == 'H':
                if name == 'NE2': q = -0.4 
                if name == 'ND1': q = -0.4 
            
            # Apply Terminal Capping Logic (Neutralize ends usually)
            if rid == 0 or rid == self.n_residues - 1:
                if name in ['N', 'CA', 'C', 'O', 'OXT', 'H1', 'H2', 'H3', 'H']: q = 0.0
            self.q_vector[k] = q
        
        # 3. Pre-calculate VdW Radii (Vectorized)
        self.vdw_radii_vector = np.array([self.VDW_RADII.get(x[2], 1.7) for x in self.static_labels])
        
        # 4. Masks
        # Mask for heavy atoms (not H) - useful for Sterics
        self.mask_heavy = np.array([not x.startswith('H') for x in self.atom_names], dtype=bool)
        
        # Mask for Hydrophobic atoms (SASA)
        hydro_res_set = {'ALA','VAL','LEU','ILE','MET','PHE','TRP','PRO','CYS'}
        self.mask_hydrophobic = np.zeros(n_atoms, dtype=bool)
        for k, (rid, name, _) in enumerate(self.static_labels):
            if self.sequence[rid] in hydro_res_set and name.startswith('C'):
                self.mask_hydrophobic[k] = True
                
        # Mask for Bonded/Neighbor Exclusions (i, i+1 residues)
        # We generally don't calculate VdW/Electrostatics for atoms in the same or adjacent residues
        res_diff_matrix = np.abs(self.atom_to_res[:, None] - self.atom_to_res[None, :])
        self.mask_non_bonded = (res_diff_matrix >= 2) 
        
        # Identify indices for specific calculations to avoid string parsing in loop
        self.idx_N_atoms = np.where(self.atom_names == 'N')[0]
        self.idx_O_atoms = np.where(self.atom_names == 'O')[0]
        self.idx_SG_atoms = np.where(self.atom_names == 'SG')[0]
        
        self._cache_initialized = True

    def energy_function(self, params):
        """
        THE CRITIC (Objective Function)
        Evaluates how "physically good" the protein structure is.
        Lower Energy = Better Fold.
        """
        if not self._cache_initialized: self._initialize_topology_cache()
        
        # ==========================================
        # STAGE CONTROLLER (Guided Relaxation)
        # ==========================================
        # Ref: Heuristic Manual Tuning ("Quantum Velcro")
        # "Gamma" = Surface Tension. High Gamma forces the protein to squeeze into a ball (Hydrophobic collapse).
        # "Constraint" = End-to-end bias. Forces the ends together to form a hairpin.
        
        # Default: "Molding Mode" (Stages 1 & 2)
        gamma = 15.0              
        constraint_strength = 50.0 
        
        # Stage 3: RELAXATION
        if self.current_stage == 3:
            gamma = 5.0                # Relax surface tension
            constraint_strength = 5.0  # Relax end-to-end bias
            
        # 1. GENERATION: Get Geometry from Quantum Parameters
        angle_vec = self._get_angles(params)
        coords, _, _ = self.build_full_structure(angle_vec)
        
        total_energy = 0.0
        
        # --- VECTORIZED DISTANCE MATRIX (The heart of the physics engine) ---
        # Calculates distance between every pair of atoms in one massive matrix op.
        diffs = coords[:, None, :] - coords[None, :, :]
        D = np.sqrt(np.sum(diffs**2, axis=-1)) + 1e-9

        # ==========================================
        # 0. END-TO-END BIAS (The Variable Magnet)
        # ==========================================
        # Guarantees the U-shape topology, preventing "Elastic Recoil".
        ca_indices = [i for i, lbl in enumerate(self.static_labels) if lbl[1] == 'CA']
        if len(ca_indices) >= 2:
            start_ca = coords[ca_indices[0]]
            end_ca = coords[ca_indices[-1]]
            dist_ends = np.linalg.norm(start_ca - end_ca)
            
            # Target: 5.5 Angstroms (Ideal for Hairpin)
            e_constraint = constraint_strength * (dist_ends - 5.5)**2
            total_energy += e_constraint

        # ==========================================
        # 1. IMPLICIT SOLVENT (SASA - Hydrophobic Effect)
        # ==========================================
        # Approximates Solvent Accessible Surface Area.
        # Logic: Hydrophobic atoms want to be surrounded by other atoms (buried), not water.
        hydro_dists = D[self.mask_hydrophobic, :]
        weights = 1.0 / (1.0 + np.exp(1.0 * (hydro_dists - 6.0))) # Sigmoid count of neighbors < 6.0A
        neighbor_counts = np.sum(weights, axis=1) - 1.0 
        burial_fractions = neighbor_counts / 15.0 # Normalize: 15 neighbors = fully buried
        burial_fractions = np.clip(burial_fractions, 0.0, 1.0)
        exposed_area = 30.0 * (1.0 - burial_fractions)
        
        total_energy += np.sum(gamma * exposed_area)

        # ==========================================
        # 2. EXPLICIT H-BONDING (The Widened Zipper)
        # ==========================================
        # Checks for N-H ... O=C patterns.
        # This is critical for secondary structure (Alpha Helices / Beta Sheets).
        e_hbond = 0.0
        for i_n in self.idx_N_atoms:
            res_d = self.atom_to_res[i_n]
            idx_ca = i_n + 1
            idx_prev_c = i_n - 2 
            
            # Construct Hydrogen position (approximate)
            if idx_prev_c < 0 or self.atom_names[idx_prev_c] != 'C':
                pos_h = coords[i_n] + np.array([0,0,1.0]); pos_n = coords[i_n]
            else:
                p_c = coords[idx_prev_c]; p_n = coords[i_n]; p_ca = coords[idx_ca]
                v_nc = p_c - p_n; v_nc /= np.linalg.norm(v_nc)
                v_nca = p_ca - p_n; v_nca /= np.linalg.norm(v_nca)
                v_h = -(v_nc + v_nca); v_h /= np.linalg.norm(v_h)
                pos_h = p_n + v_h * 1.01; pos_n = p_n

            # Check all Oxygens
            o_coords = coords[self.idx_O_atoms]
            o_res = self.atom_to_res[self.idx_O_atoms]
            valid_mask = np.abs(o_res - res_d) >= 2 # Don't bond with immediate neighbors
            
            if not np.any(valid_mask): continue
            
            valid_o_coords = o_coords[valid_mask]
            d_ho = np.linalg.norm(valid_o_coords - pos_h, axis=1)
            close_mask = d_ho < 3.5
            if not np.any(close_mask): continue
            
            final_d_ho = d_ho[close_mask]
            final_o_coords = valid_o_coords[close_mask]
            
            # Angle check: H-bond must be roughly linear
            v_hn = pos_n - pos_h; v_hn /= np.linalg.norm(v_hn)
            v_ho = final_o_coords - pos_h
            norms = np.linalg.norm(v_ho, axis=1)[:, None]
            v_ho /= norms
            angle_cos = np.dot(v_ho, v_hn) 
            
            ang_mask = angle_cos < -0.4 
            
            # Energy calculation
            radial_term = np.exp(-(final_d_ho - 2.0)**2 / 0.5)
            angular_term = (np.abs(angle_cos) - 0.4) * 2.0 
            
            # Strength -25.0 is very strong ("Super Glue") to force folding
            term = -25.0 * radial_term * angular_term * ang_mask
            e_hbond += np.sum(term)

        total_energy += e_hbond

        # ==========================================
        # 3. ELECTROSTATICS (Coulomb)
        # ==========================================
        # q1*q2 / r^2
        Q_mat = np.outer(self.q_vector, self.q_vector)
        elec_mask = np.triu(self.mask_non_bonded, k=1) & (np.abs(Q_mat) > 0.0001)
        if np.any(elec_mask):
            r_elec = D[elec_mask]
            r_elec = np.maximum(r_elec, 1.0) # Cap distance to prevent infinity
            q_prod = Q_mat[elec_mask]
            total_energy += np.sum(83.0 * q_prod / (r_elec**2)) # 83.0 is approx Coulomb constant in these units

        # ==========================================
        # 3b. DISULFIDE BONDS (Cysteine Bridges)
        # ==========================================
        if len(self.idx_SG_atoms) > 1:
            sg_dists = D[np.ix_(self.idx_SG_atoms, self.idx_SG_atoms)]
            sg_mask = np.triu(np.ones_like(sg_dists, dtype=bool), k=1)
            valid_dists = sg_dists[sg_mask]
            
            # Attraction
            bond_strengths = np.exp(-(valid_dists - 2.05)**2 / 0.5)
            active_bonds = (valid_dists < 3.0)
            total_energy -= np.sum(25.0 * bond_strengths * active_bonds)
            
            # Valence Penalty (Don't form 3 bonds with one Sulfur)
            full_strengths = np.exp(-(sg_dists - 2.05)**2 / 0.5) * (sg_dists < 3.0)
            np.fill_diagonal(full_strengths, 0.0)
            saturation = np.sum(full_strengths, axis=1)
            overload = saturation - 1.0
            penalty_mask = overload > 0.1
            if np.any(penalty_mask):
                total_energy += np.sum(40.0 * (overload[penalty_mask])**2)

        # ==========================================
        # 4. STERICS (Softened Lennard-Jones)
        # ==========================================
        # Prevents atoms from being in the same place.
        Sigma_mat = self.vdw_radii_vector[:, None] + self.vdw_radii_vector[None, :]
        heavy_mat = self.mask_heavy[:, None] & self.mask_heavy[None, :]
        vdw_mask = np.triu(self.mask_non_bonded & heavy_mat, k=1)
        
        if np.any(vdw_mask):
            r_vdw = D[vdw_mask]
            s_vdw = Sigma_mat[vdw_mask]
            collision_mask = r_vdw < s_vdw # Only calculate if overlapping
            
            if np.any(collision_mask):
                r_col = r_vdw[collision_mask]
                s_col = s_vdw[collision_mask]
                
                # Standard Repulsion term
                term = (s_col / (r_col + 0.1)) ** 12
                
                # SOFTENING: Log-cap to prevent infinite energy (gradient explosion)
                high_e = term > 50.0
                if np.any(high_e): term[high_e] = 50.0 + np.log(term[high_e] - 49.0)
                
                total_energy += np.sum(0.1 * term)

        # ==========================================
        # LOCALS (Rotamer, Quadrupole, Rama, Geometry)
        # ==========================================
        angle_dict = {f"{x['res']}_{x['type']}": val for x, val in zip(self.dof_map, angle_vec)}
        
        # 5. Rotamers (Side chain preferences)
        total_energy += self._calculate_rotamer_energy(angle_dict)
        
        # 6. Aromatic Stacking (Pi-Pi interactions)
        total_energy += self._calculate_aromatic_quadrupole(coords, self.static_labels, self.atom_to_res)
        
        # 7. Ramachandran (Backbone torsion preferences)
        for i in range(self.n_residues):
             if f"{i}_phi" in angle_dict and f"{i}_psi" in angle_dict:
                phi = angle_dict[f"{i}_phi"]; psi = angle_dict[f"{i}_psi"]
                aa = self.sequence[i]
                
                # Ideal regions for Helix (-1, -0.8) and Sheet (-2.3, 2.4)
                d_helix = (phi - (-1.0))**2 + (psi - (-0.8))**2
                d_sheet = (phi - (-2.3))**2 + (psi - (2.4))**2
                
                if aa == 'G': # Glycine is flexible
                    d_helix_L = (phi - (1.0))**2 + (psi - (0.8))**2
                    d_sheet_L = (phi - (2.3))**2 + (psi - (-2.4))**2
                    dist_best = min(d_helix, d_sheet, d_helix_L, d_sheet_L)
                    total_energy += -3.0 * np.exp(-dist_best/0.6)
                else: # General case with forbidden regions
                    d_forbidden = (phi - (-2.0))**2 + (psi - (1.0))**2
                    term = -3.0 * np.exp(-d_helix/0.6) - 3.0 * np.exp(-d_sheet/0.6) + 5.0 * np.exp(-d_forbidden/1.0)
                    total_energy += term

        # 8. Geometry Integrity (Chirality, Planarity)
        total_energy += self._calculate_geometry_integrity(coords, self.static_labels, self.atom_to_res)

        if self.tracker:
            self.tracker.log(total_energy)
        
        return total_energy

    # --- KEEPING HELPERS (Standard implementations) ---
    def _calculate_rotamer_energy(self, angle_dict):
        """
        Ensures side chains adopt physically observed angles (gauche+, gauche-, trans).
        """
        energy = 0.0
        for i in range(self.n_residues):
            res_name = self.sequence[i]
            key = f"{i}_chi1"
            if key in angle_dict:
                chi = angle_dict[key]
                if res_name in ['VAL', 'ILE', 'THR']:
                    d_trans = (chi - 3.14159)**2; d_gplus = (chi - (-1.047))**2
                    energy += -3.0 * (np.exp(-d_trans/0.5) + np.exp(-d_gplus/0.5))
                elif res_name == 'PRO':
                    d_down = (chi - (-0.5))**2; d_up = (chi - (0.5))**2
                    energy += 10.0 * min(d_down, d_up)
                elif res_name in ['TRP', 'PHE', 'TYR', 'HIS']:
                    d_trans = (chi - 3.14159)**2; d_gplus = (chi - (-1.047))**2
                    energy += -2.0 * (np.exp(-d_trans/0.5) + np.exp(-d_gplus/0.5))
                else:
                    energy += 1.0 * (1.0 + np.cos(3.0 * chi))
        return energy

    def _calculate_aromatic_quadrupole(self, coords, labels, atom_to_res_idx):
        """
        Calculates stacking energy between aromatic rings (Phe, Tyr, Trp).
        Uses normal vectors to detect parallel stacking.
        """
        aromatics = []
        res_indices = np.unique(atom_to_res_idx)
        for r_idx in res_indices:
            if self.sequence[r_idx] in ['PHE', 'TYR', 'TRP']:
                mask = (atom_to_res_idx == r_idx)
                r_coords = coords[mask]
                r_names = self.atom_names[mask]
                
                ring_mask = np.isin(r_names, ['CG','CD1','CD2','CE1','CE2','CZ'])
                ring_atoms = r_coords[ring_mask]
                
                if len(ring_atoms) > 2:
                    centroid = np.mean(ring_atoms, axis=0)
                    v1 = ring_atoms[1] - ring_atoms[0]
                    v2 = ring_atoms[2] - ring_atoms[0]
                    normal = np.cross(v1, v2); normal /= (np.linalg.norm(normal)+1e-9)
                    aromatics.append((centroid, normal))
        
        energy_pi = 0.0
        n_aro = len(aromatics)
        if n_aro < 2: return 0.0
        
        for i in range(n_aro):
            for j in range(i+1, n_aro):
                c1, n1 = aromatics[i]; c2, n2 = aromatics[j]
                dist = np.linalg.norm(c1 - c2)
                if dist > 7.0: continue
                alignment = abs(np.dot(n1, n2))
                # T-stacking vs Parallel Stacking
                if alignment < 0.3 and 4.5 < dist < 6.0:
                     energy_pi -= 4.0 * np.exp(-(dist - 5.0)**2)
                elif alignment > 0.8 and 3.4 < dist < 4.5:
                     energy_pi -= 5.0 * np.exp(-(dist - 3.8)**2)
        return energy_pi

    def _calculate_geometry_integrity(self, coords, labels, atom_to_res_idx):
        """
        Penalizes physically impossible geometries (e.g. L-amino acids turning into D-amino acids).
        """
        energy = 0.0
        res_map = {}
        for k, lbl in enumerate(labels):
            r = lbl[0]; atom = lbl[1]
            if r not in res_map: res_map[r] = {}
            res_map[r][atom] = k
            
        for r in range(self.n_residues):
            atoms = res_map.get(r, {})
            res_name = self.sequence[r]
            
            # PRO Ring closure penalty
            if res_name == 'PRO' and 'CD' in atoms and 'N' in atoms:
                 d = np.linalg.norm(coords[atoms['CD']] - coords[atoms['N']])
                 if abs(d - 1.47) > 0.1: energy += 50.0 * (d - 1.47)**2
            
            # Chirality check (Ensure L-amino acids)
            if 'CA' in atoms and 'N' in atoms and 'C' in atoms and 'CB' in atoms:
                ca = coords[atoms['CA']]; n = coords[atoms['N']]
                c = coords[atoms['C']]; cb = coords[atoms['CB']]
                volume = np.dot(np.cross(n-ca, c-ca), cb-ca)
                if volume < 1.0: energy += 50.0 * (1.0 - volume)**2
            
            # Peptide Planarity (Omega angle should be 180 or 0)
            if r < self.n_residues - 1:
                next_atoms = res_map.get(r+1, {})
                if 'C' in atoms and 'CA' in atoms and 'N' in next_atoms and 'CA' in next_atoms:
                    idx1, idx2, idx3, idx4 = atoms['CA'], atoms['C'], next_atoms['N'], next_atoms['CA']
                    p1, p2, p3, p4 = coords[idx1], coords[idx2], coords[idx3], coords[idx4]
                    b1 = p2-p1; b2=p3-p2; b3=p4-p3
                    n1 = np.cross(b1, b2); n1/=np.linalg.norm(n1)
                    n2 = np.cross(b2, b3); n2/=np.linalg.norm(n2)
                    parallelism = np.dot(n1, n2)
                    
                    next_seq = self.sequence[r+1]
                    if next_seq == 'PRO': twist_penalty = min(1.0 - parallelism, 1.0 + parallelism)
                    else: twist_penalty = 1.0 - parallelism
                    
                    if twist_penalty > 0.05: energy += 20.0 * twist_penalty
        return energy

    def get_smart_initialization(self, n_attempts=20, seed=None):
        """
        Samples random parameters to find a good starting point (Basin Hopping).
        This avoids getting stuck in high-energy states immediately.
        
        REPRODUCIBILITY:
        Uses a hash of the sequence to seed the random number generator. 
        This ensures that every run with the same sequence starts from the same 
        initial geometry, allowing you to test energy function changes reliably.
        """
        if seed is not None:
            # Create a deterministic seed from the protein sequence
            seed = int(hashlib.sha256(self.sequence.encode('utf-8')).hexdigest(), 16) % (2**32)
        
        rng = np.random.default_rng(seed)
        
        print(f"--- SCOUTING: Checking {n_attempts} starting points ---")
        print(f" > Deterministic Seed: {seed} (Derived from Sequence)")
        
        best_params = None
        best_energy = float('inf')
        for i in range(n_attempts):
            trial_params = rng.uniform(-0.8, 0.8, self.n_params)
            e = self.energy_function(trial_params)
            if e < best_energy:
                best_energy = e
                best_params = trial_params
        print(f" > Best Start Found: Energy {best_energy:.2f}")
        return best_params

    def fold(self, max_iter=2000, initial_params=None):
        """
        MAIN EXECUTION LOOP
        Runs the 3-stage optimization curriculum.
        """
        print(f"--- STARTING QUANTUM FOLDING ---")
        self.tracker = LandscapeTracker() # Start Tracker

        # Initialization
        if initial_params is None:
            init_params = self.get_smart_initialization(n_attempts=max_iter)
        else:
            init_params = initial_params
        
        # STAGE 1: COLLAPSE
        # High Gamma (15.0) + Magnet Active
        # Purpose: Force the protein into a ball rapidly.
        print("Stage 1: Mechanical Collapse (High Force)...")
        self.tracker.mark_stage("Stage1")
        self.current_stage = 1
        res_1 = minimize(self.energy_function, init_params, method='COBYLA', options={'maxiter': max_iter, 'rhobeg': 1.0})
        print(f" > Collapse Energy: {res_1.fun:.2f}")

        # STAGE 2: REFINE
        # High Gamma (15.0) + Magnet Active + Precise Gradient Descent
        # Purpose: Fix local clashes while keeping the globular shape.
        print("Stage 2: Physics Refinement (High Force)...")
        self.tracker.mark_stage("Stage2")
        self.current_stage = 2
        res_2 = minimize(self.energy_function, res_1.x, method='SLSQP', tol=1e-6, options={'maxiter': max_iter, 'disp': True})
        print(f" > Refinement Energy: {res_2.fun:.2f}")
        
        # STAGE 3: RELAX
        # Low Gamma (2.0) + Magnet REMOVED
        # Purpose: Let the protein "breathe". H-bonds and Electrostatics take over
        # to find the native state.
        print("Stage 3: Natural Relaxation (Releasing Constraints)...")
        self.tracker.mark_stage("Stage3")
        self.current_stage = 3 
        res_3 = minimize(self.energy_function, res_2.x, method='SLSQP', tol=1e-6, options={'maxiter': max_iter, 'disp': True})
        print(f" > Relaxation Energy (Final Energy): {res_3.fun:.2f}")
        
        coords, labels, bonds = self.build_full_structure(self._get_angles(res_3.x))
        return coords, labels, bonds, self.tracker, res_3.x, res_3.fun

    def save_pdb(self, coords, labels, filename="structure.pdb", energy=0.0):
        """
        Saves the result to a PDB file viewable in PyMOL or Chimera.
        """
        with open(filename, 'w') as f:
            f.write(f"REMARK   1 ENERGY: {energy:.3f}\n")
            for k, (pos, (res_id, atom_name, elem)) in enumerate(zip(coords, labels)):
                res_name = self.sequence[res_id]
                f.write(f"ATOM  {k+1:>5}  {atom_name:<4} {res_name:>3} A{res_id+1:>4}    {pos[0]:8.3f}{pos[1]:8.3f}{pos[2]:8.3f}  1.00  0.00           {elem:>2}\n")

# ==========================================
# 4. ORCHESTRATOR: ENSEMBLE MANAGER
# ==========================================
class EnsembleFoldingManager:
    """
    Manages multiple independent folding runs (Monte Carlo / Multi-Start)
    """
    def __init__(self, folder_instance):
        self.folder = folder_instance
        self.results = [] 
    
    def prime_circuit(self, target_type='helix', seed=42):
        """
        Smart Initialization: Pre-optimizes circuit to output Secondary Structure angles.
        """
        print(f"--- PRIMING CIRCUIT FOR {target_type.upper()} ---")
        rng = np.random.default_rng(seed)

        if target_type == 'helix':
            t_phi, t_psi = np.deg2rad(-60.0), np.deg2rad(-45.0)
        elif target_type == 'sheet':
            t_phi, t_psi = np.deg2rad(-135.0), np.deg2rad(135.0)
        else:
            return rng.uniform(-0.8, 0.8, self.folder.n_params)

        targets = np.zeros(self.folder.total_angles)
        masks = np.zeros(self.folder.total_angles)
        
        for i, dof in enumerate(self.folder.dof_map):
            if dof['type'] == 'phi': targets[i] = t_phi; masks[i] = 1.0
            elif dof['type'] == 'psi': targets[i] = t_psi; masks[i] = 1.0
            
        def priming_cost(params):
            curr = self.folder._get_angles(params)
            diff = (curr - targets + np.pi) % (2 * np.pi) - np.pi
            return np.sum((diff * masks)**2)

        init_guess = rng.uniform(-0.1, 0.1, self.folder.n_params)
        res = minimize(priming_cost, init_guess, method='COBYLA', options={'maxiter': 200})
        print(f" > Priming Error: {res.fun:.4f}")
        return res.x

    def run_ensemble(self, n_runs=5, prime_strategy='mixed'):
        print(f"=== STARTING ENSEMBLE RUN ({n_runs} Trajectories) ===")
        self.results = []

        # Create a deterministic seed from the protein sequence
        # Retrieve the protein sequence from the folder object
        seed = int(hashlib.sha256(self.folder.sequence.encode('utf-8')).hexdigest(), 16) % (2**32)
        
        for i in range(n_runs):
            print(f"\n>> REPLICA {i+1}/{n_runs}")
            
            # Strategy Selection
            if prime_strategy == 'mixed':
                if i % 3 == 0: strat = 'helix'
                elif i % 3 == 1: strat = 'sheet'
                else: strat = 'random'
            else: strat = prime_strategy
                
            # Initialization
            if strat == 'random':
                start_params = self.folder.get_smart_initialization(n_attempts=50, seed=seed+i)
            else:
                start_params = self.prime_circuit(target_type=strat, seed=seed+i)
            
            # Execute Fold
            coords, _, _, tracker, final_params, final_energy = self.folder.fold(max_iter=1000, initial_params=start_params)
            
            print(f" >> Replica {i+1} Final Energy: {final_energy:.2f}")
            self.results.append({
                'id': i, 'seed': seed+i, 'type': strat, 'energy': final_energy,
                'coords': coords, 'params': final_params, 'tracker': tracker
            })

    def evaluate_best(self):
        if not self.results: return None, None

        sorted_results = sorted(self.results, key=lambda x: x['energy'])
        best = sorted_results[0]
        
        print(f"\n=== ENSEMBLE EVALUATION ===")
        print(f"Best Candidate: ID {best['id']} (Init: {best['type']})")
        print(f"Lowest Energy:  {best['energy']:.4f}")
        
        if len(self.results) > 1:
            StabilityAnalyzer.analyze_convergence(self.results)

        return best

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import hashlib
from copy import deepcopy
from mpl_toolkits.mplot3d import Axes3D
try:
    from qiskit.circuit.library import efficient_su2
    from qiskit.quantum_info import Statevector
    QISKIT_AVAILABLE = True
except ImportError:
    efficient_su2 = None
    Statevector = None
    QISKIT_AVAILABLE = False
from scipy.optimize import minimize
from scipy.spatial.distance import pdist, squareform
import numpy as np
import matplotlib.pyplot as plt
import hashlib
from copy import deepcopy
from mpl_toolkits.mplot3d import Axes3D
#from qiskit.circuit.library import efficient_su2
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import Statevector
from scipy.optimize import minimize
from scipy.spatial.distance import pdist, squareform
import numpy as np
from qiskit import transpile , QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator

# ==========================================
# 1. UTILITY: TRACKING & LOGGING
# ==========================================
class LandscapeTracker:
    def __init__(self):
        self.history = []
        self.stage_markers = []
        self.current_iter = 0

    def log(self, energy):
        self.history.append(energy)
        self.current_iter += 1

    def mark_stage(self, name):
        self.stage_markers.append((self.current_iter, name))

# ==========================================
# 2. ANALYSIS: STABILITY & CONVERGENCE (KABSCH)
# ==========================================
class StabilityAnalyzer:
    """
    Tools to evaluate if the folding results are structurally consistent.
    Implements the Kabsch algorithm for optimal superposition.
    """
    
    @staticmethod
    def kabsch_rmsd(P, Q):
        """
        Calculates the RMSD between two sets of coordinates P and Q
        after optimally rotating P to align with Q.
        """
        # 1. Centering
        P_centered = P - np.mean(P, axis=0)
        Q_centered = Q - np.mean(Q, axis=0)
        
        # 2. Covariance Matrix
        H = np.dot(P_centered.T, Q_centered)
        
        # 3. SVD
        V, S, Wt = np.linalg.svd(H)
        
        # 4. Rotation Matrix
        d = (np.linalg.det(V) * np.linalg.det(Wt)) < 0.0
        if d: 
            S[-1] = -S[-1]
            V[:, -1] = -V[:, -1]
        
        R = np.dot(V, Wt)
        
        # 5. Rotate and Diff
        P_rotated = np.dot(P_centered, R)
        diff = P_rotated - Q_centered
        rms = np.sqrt(np.mean(np.sum(diff**2, axis=1)))
        
        return rms, P_rotated + np.mean(Q, axis=0) # Return RMSD and Aligned Coords

    @staticmethod
    def analyze_convergence(results, top_k=5):
        """
        Calculates pairwise RMSD between the top K lowest energy structures.
        """
        # Sort by Energy (lowest first)
        sorted_results = sorted(results, key=lambda x: x['energy'])
        best_k = sorted_results[:top_k]
        n = len(best_k)
        
        if n < 2: return
        
        print(f"\n--- CONVERGENCE ANALYSIS (Top {n} Structures) ---")
        
        rmsd_matrix = np.zeros((n, n))
        
        # Print Header
        print("      ", end="")
        for i in range(n): print(f" #{i:<4}", end="")
        print("\n" + "-"*60)
        
        for i in range(n):
            print(f"Ref #{i} |", end="")
            for j in range(n):
                if i == j:
                    rmsd_matrix[i, j] = 0.0
                else:
                    # Note: Using all atoms for RMSD. Ideally filter for 'CA' only.
                    rmsd, _ = StabilityAnalyzer.kabsch_rmsd(best_k[i]['coords'], best_k[j]['coords'])
                    rmsd_matrix[i, j] = rmsd
                
                print(f" {rmsd_matrix[i, j]:.2f} ", end="")
            print(f"  (E={best_k[i]['energy']:.1f})")
            
        avg_rmsd = np.sum(rmsd_matrix) / (n*(n-1))
        print(f"\nAverage Pairwise RMSD: {avg_rmsd:.2f} Angstroms")
        
        if avg_rmsd < 2.0:
            print(">>> VERDICT: STABLE. High confidence in prediction.")
        elif avg_rmsd < 4.5:
            print(">>> VERDICT: FLEXIBLE. Core is stable, loops vary.")
        else:
            print(">>> VERDICT: UNSTABLE. No dominant basin found.")

# ==========================================
# 3. CORE: QUANTUM FOLDER
# ==========================================
class QuantumBiophysicsFolder:
    """
    A Hybrid Quantum-Classical Protein Folder.
    
    ARCHITECTURE:
    1. Quantum Actor (The Generator): 
       Uses a parameterized quantum circuit (VQE ansatz) to generate a probability distribution.
       These probabilities are mapped to physical torsion angles (phi, psi, chi).
       
    2. Classical Critic (The Energy Function):
       Constructs the 3D geometry from those angles and evaluates its physical stability
       using a custom force field (hydrophobicity, electrostatics, H-bonds, etc.).
       
    3. Optimization Loop:
       Classical optimizers (COBYLA/SLSQP) tune the quantum circuit parameters to minimize the energy.

    REFERENCES:
    1. Hydrophobicity: Kyte, J., & Doolittle, R. F. (1982). A simple method for displaying the hydropathic character of a protein.
    2. Electrostatics: CHARMM22 / OPLS-AA Force Fields (Approximated partial charges).
    3. VdW Radii: Bondi, A. (1964). Van der Waals volumes and radii.
    4. Topology: Engh, R. A., & Huber, R. (1991). Accurate bond and angle parameters for X-ray protein structure refinement.
    5. Heuristics: Manual tuning ("Quantum Velcro") for folding convergence.
    """

    def __init__(
        self,
        sequence,
        force_field='charmm',
        chi_mode='all',
        selective_chi_map=None,
    ):
        """
        Initialize the folder.
        
        Args:
            sequence (str): Amino acid sequence (e.g., 'MAG').
            force_field (str): 'charmm', 'amber', or 'opls'. Determines partial charges.
        """
        self.sequence = sequence.upper()
        self.n_residues = len(sequence)
        self.force_field = force_field.lower()
        self.chi_mode = chi_mode
        self.selective_chi_map = selective_chi_map or {}
        
        print(f"--- INITIALIZING QUANTUM BIOPHYSICS FOLDER ---")
        print(f"--- FORCE FIELD: {self.force_field.upper()} ---")
        
        # --- PARAMETERS (Force Field Constants) ---

        # 1. HYDROPHOBICITY SCALE
        # Ref: Kyte, J., & Doolittle, R. F. (1982). J. Mol. Biol. 157, 105-132.
        self.HYDROPHOBICITY = {
            'I': 4.5, 'V': 4.2, 'L': 3.8, 'F': 2.8, 'C': 2.5,
            'M': 1.9, 'A': 1.8, 'G': -0.4, 'T': -0.7, 'S': -0.8,
            'W': -0.9, 'Y': -1.3, 'P': -1.6, 'H': -3.2, 'E': -3.5,
            'Q': -3.5, 'D': -3.5, 'N': -3.5, 'K': -3.9, 'R': -4.5
        }
        
        # 2. PARTIAL CHARGES (Coulomb's Law)
        # We now support switching between major force field approximations.
        # While coarse-grained, these capture the distinct dipole strengths of each FF.
        
        # BASE (Shared Ions)
        common_charges = {
            'OXT': -1.0, 
            'NZ': 1.0, 'NH1': 0.5, 'NH2': 0.5, 
            'OD1': -0.5, 'OD2': -0.5, 'OE1': -0.5, 'OE2': -0.5,
            'ND2': 0.5, 'NE2': 0.5, 
            'SG': -0.1, 'SD': -0.1,
            'HE2': 0.4, 'ND1': -0.4, # His
        }

        # CHARMM22 (The original default)
        # Strong dipoles, balanced C-alpha.
        charmm_charges = {
            'N': -0.47, 'H': 0.31, 'CA': 0.07, 'C': 0.51, 'O': -0.51,
            'OG': -0.4, 'HG': 0.4, 'OG1': -0.4, 'HG1': 0.4, 'OH': -0.4, 'HH': 0.4,
            'NE1': -0.3, 'HE1': 0.3
        }
        
        # AMBER (ff94/99/14SB approx)
        # N is slightly less negative, C=O is very polar. C-alpha is often neutral.
        amber_charges = {
            'N': -0.42, 'H': 0.27, 'CA': 0.00, 'C': 0.60, 'O': -0.57,
            'OG': -0.6, 'HG': 0.4, 'OG1': -0.6, 'HG1': 0.4, 'OH': -0.5, 'HH': 0.4, # Ambient hydroxyls often stronger
            'NE1': -0.4, 'HE1': 0.3
        }

        # OPLS-AA
        # Very standardized backbone dipoles (+0.5/-0.5).
        opls_charges = {
            'N': -0.50, 'H': 0.30, 'CA': 0.14, 'C': 0.50, 'O': -0.50,
            'OG': -0.7, 'HG': 0.4, 'OG1': -0.7, 'HG1': 0.4, 'OH': -0.7, 'HH': 0.4,
            'NE1': -0.4, 'HE1': 0.35
        }

        # Select Strategy
        self.CHARGES = common_charges.copy()
        if self.force_field == 'amber':
            self.CHARGES.update(amber_charges)
        elif self.force_field == 'opls':
            self.CHARGES.update(opls_charges)
        else: # Default to CHARMM
            if self.force_field != 'charmm':
                print(f" > Warning: Unknown force field '{self.force_field}'. Defaulting to CHARMM.")
            self.CHARGES.update(charmm_charges)
        
        # 3. VAN DER WAALS RADII (Angstroms)
        # Ref: Bondi, A. (1964). J. Phys. Chem. 68, 441-451.
        self.VDW_RADII = {'H': 0.6, 'C': 1.7, 'N': 1.55, 'O': 1.52, 'S': 1.8}
        
        # 4. SIDE CHAIN TOPOLOGY
        # Ref: Engh, R. A., & Huber, R. (1991). Acta Cryst. A47, 392-400.
        self.SIDE_CHAIN_TOPO = {
            'G': [],
            'A': [('CB', 'CA', 1.53, 1.91, 2.1)],
            
            # Hydrophobic
            'V': [('CB', 'CA', 1.53, 1.91, 'chi1'), 
                  ('CG1', 'CB', 1.52, 1.91, 'chi2'), ('CG2', 'CB', 1.52, 1.91, 'chi2_branch')],
            'L': [('CB', 'CA', 1.53, 1.91, 'chi1'), 
                  ('CG', 'CB', 1.52, 1.91, 'chi2'), 
                  ('CD1', 'CG', 1.52, 1.91, 'chi3'), ('CD2', 'CG', 1.52, 1.91, 'chi3_branch')],
            'I': [('CB', 'CA', 1.53, 1.91, 'chi1'), 
                  ('CG1', 'CB', 1.54, 1.91, 'chi2'), ('CD1', 'CG1', 1.52, 1.91, 'chi3'),
                  ('CG2', 'CB', 1.54, 1.91, 'chi2_branch')],
            'M': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('SD', 'CG', 1.81, 1.91, 'chi3'), ('CE', 'SD', 1.79, 1.76, 'chi4')],
            'P': [('CB', 'CA', 1.53, 1.80, 'chi1'), ('CG', 'CB', 1.50, 1.82, 'chi2'),
                  ('CD', 'CG', 1.52, 1.83, 'chi3')], 

            # Aromatic
            'F': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.50, 1.91, 'chi2'),
                  ('CD1', 'CG', 1.39, 2.09, 1.57), ('CD2', 'CG', 1.39, 2.09, -1.57),
                  ('CE1', 'CD1', 1.39, 2.09, 3.14), ('CE2', 'CD2', 1.39, 2.09, 3.14),
                  ('CZ', 'CE1', 1.39, 2.09, 0.0)],
            'Y': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.50, 1.91, 'chi2'),
                  ('CD1', 'CG', 1.39, 2.09, 1.57), ('CD2', 'CG', 1.39, 2.09, -1.57),
                  ('CE1', 'CD1', 1.39, 2.09, 3.14), ('CE2', 'CD2', 1.39, 2.09, 3.14),
                  ('CZ', 'CE1', 1.39, 2.09, 0.0), 
                  ('OH', 'CZ', 1.37, 2.09, 3.14), ('HH', 'OH', 0.96, 1.83, 'chi3')], 
            'W': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.50, 1.91, 'chi2'),
                  ('CD1', 'CG', 1.37, 2.15, 1.0), ('CD2', 'CG', 1.43, 2.15, -1.0),
                  ('NE1', 'CD1', 1.38, 1.90, 3.14), ('HE1', 'NE1', 1.01, 2.09, 0.0), 
                  ('CE2', 'CD2', 1.40, 1.90, 0.0), ('CE3', 'CD2', 1.40, 2.30, 3.14), 
                  ('CZ2', 'CE2', 1.40, 2.10, 0.0), ('CZ3', 'CE3', 1.40, 2.10, 0.0), 
                  ('CH2', 'CZ2', 1.40, 2.10, 0.0)], 

            # Polar / Charged
            'S': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('OG', 'CB', 1.42, 1.91, 'chi2'),
                  ('HG', 'OG', 0.96, 1.83, 'chi3')], 
            'T': [('CB', 'CA', 1.53, 1.91, 'chi1'), 
                  ('OG1', 'CB', 1.43, 1.91, 'chi2'), ('HG1', 'OG1', 0.96, 1.83, 'chi3'), 
                  ('CG2', 'CB', 1.53, 1.91, 'chi2_branch')],
            'C': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('SG', 'CB', 1.81, 1.91, 'chi2')],
            'D': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('OD1', 'CG', 1.25, 2.0, 1.0), ('OD2', 'CG', 1.25, 2.0, -1.0)],
            'N': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('OD1', 'CG', 1.23, 2.09, 0.0), ('ND2', 'CG', 1.32, 2.09, 3.14)],
            'E': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('CD', 'CG', 1.52, 1.91, 'chi3'), ('OE1', 'CD', 1.25, 2.0, 1.0), ('OE2', 'CD', 1.25, 2.0, -1.0)],
            'Q': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('CD', 'CG', 1.52, 1.91, 'chi3'), ('OE1', 'CD', 1.23, 2.09, 0.0), ('NE2', 'CD', 1.32, 2.09, 3.14)],
            'K': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('CD', 'CG', 1.52, 1.91, 'chi3'), ('CE', 'CD', 1.52, 1.91, 'chi4'),
                  ('NZ', 'CE', 1.49, 1.91, 'chi5')],
            'R': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.52, 1.91, 'chi2'),
                  ('CD', 'CG', 1.52, 1.91, 'chi3'), ('NE', 'CD', 1.46, 1.91, 'chi4'),
                  ('CZ', 'NE', 1.33, 2.15, 'chi5'), ('NH1', 'CZ', 1.33, 2.10, 0.0), ('NH2', 'CZ', 1.33, 2.10, 3.14)],
            'H': [('CB', 'CA', 1.53, 1.91, 'chi1'), ('CG', 'CB', 1.50, 1.91, 'chi2'),
                  ('ND1', 'CG', 1.38, 2.15, 1.0), ('CD2', 'CG', 1.36, 2.15, -1.0),
                  ('CE1', 'ND1', 1.32, 1.90, 0.0), 
                  ('NE2', 'CD2', 1.32, 1.90, 0.0), ('HE2', 'NE2', 1.01, 2.09, 0.0)], 
            
            'DEFAULT': [('CB', 'CA', 1.53, 1.91, 'chi1')]
        }

        # --- QUANTUM SETUP ---
        # 1. Map sequence to Degrees of Freedom (DoF)
        self.dof_map = []
        for i, aa in enumerate(self.sequence):
            self.dof_map.append({'res': i, 'type': 'phi'})
            self.dof_map.append({'res': i, 'type': 'psi'})

            topo = self.SIDE_CHAIN_TOPO.get(aa, self.SIDE_CHAIN_TOPO['DEFAULT'])
            chis = set()
            for atom in topo:
                tor = atom[4]
                if isinstance(tor, str) and 'chi' in tor:
                    chis.add(tor.replace('_branch', ''))

            allowed_chis = self._allowed_chis_for_residue(i, aa, chis)
            for k in allowed_chis:
                self.dof_map.append({'res': i, 'type': k})
        
        self.total_angles = len(self.dof_map)
        
        # 2. Holographic Encoding
        # We only need log2(N) qubits to represent N angles in terms of statevector capacity.
        # This makes the algorithm scalable.
        self.n_qubits = max(2, int(np.ceil(np.log2(self.total_angles))))
        
        # 3. The Ansatz (The "Actor")
        # 'efficient_su2' is a heuristic circuit often used in VQE.
        # 'reps' controls depth. More reps = more expressive = harder to train.
        self.reps = int(np.ceil(self.total_angles / self.n_qubits)) + 2

        if QISKIT_AVAILABLE:
            self.ansatz = efficient_su2(self.n_qubits, reps=self.reps, entanglement='circular')
            self.n_params = self.ansatz.num_parameters
        else:
            self.ansatz = None
            self.n_params = 1
        
        self.current_stage = 1
        
        # --- PRE-COMPUTE CACHE (Optimization) ---
        # We run the structure builder once with dummy data to figure out which atom is which.
        # This lets us optimize the energy function using Vectorization (NumPy) instead of slow loops.
        self._cache_initialized = False
        self._initialize_topology_cache()
        self.tracker = None  # TRACKER REFERENCE

    def _allowed_chis_for_residue(self, res_idx, aa, available_chis):
        """
        Decide which chi DOFs to expose for a residue.
        """

        available = sorted(set(available_chis), key=lambda x: (len(x), x))

        if self.chi_mode == "all":
            return available

        if self.chi_mode == "chi1_only":
            return [c for c in available if c == "chi1"]

        if self.chi_mode == "selective":
            allowed = self.selective_chi_map.get(aa, ["chi1"])
            allowed = set(allowed)
            return [c for c in available if c in allowed]

        raise ValueError(f"Unknown chi_mode: {self.chi_mode}")

    def _get_angles(self, params, backend=None, shots=4096):
        """
        Hardware-compatible torsion extraction:
        (measurement counts) -> (expectations/correlations) -> (torsion angles)

        Key ideas:
        - Measure in multiple bases (Z, X, Y) to get richer features without statevector phases.
        - Use sparse pair correlations (nearest neighbors) to add more signal.
        - Decode per-qubit angles using Bloch-sphere style mapping:
            phi_i = atan2(<Y_i>, <X_i>)
            theta_i = arccos(clip(<Z_i>))
        then use correlations to create extra "psi-like" angles.
        - Finally, deterministically expand/compress to self.total_angles.
        """

        # ----------------------------
        # 0) Backend default
        # ----------------------------
        if backend is None:
            backend = AerSimulator()  # local simulator; replace with IBM backend for real hardware

        # ----------------------------
        # 1) Bind parameters to ansatz
        # ----------------------------
        param_dict = dict(zip(self.ansatz.parameters, params))
        base_qc = self.ansatz.assign_parameters(param_dict)

        n = self.n_qubits  # number of system qubits in ansatz

        # ----------------------------
        # Helpers
        # ----------------------------
        def _measured_in_basis(qc, basis: str):
            """
            Return a NEW circuit that measures all qubits in the given basis.
            basis: 'Z', 'X', or 'Y'
            """
            c = qc.copy()

            # Ensure classical bits exist (measure_all adds them if needed)
            # Apply basis change before measuring:
            if basis.upper() == "X":
                # Measure X by H then measure Z
                for q in range(n):
                    c.h(q)
            elif basis.upper() == "Y":
                # Measure Y by Sdg then H then measure Z
                for q in range(n):
                    c.sdg(q)
                    c.h(q)
            elif basis.upper() == "Z":
                pass
            else:
                raise ValueError("basis must be one of {'Z','X','Y'}")

            c.measure_all()
            return c

        def _run_counts(qc):
            tqc = transpile(qc, backend)
            job = backend.run(tqc, shots=shots)
            result = job.result()
            return result.get_counts()

        def _bit_to_pm1(bit_char: str) -> int:
            # Qiskit: '0' -> +1 eigenvalue, '1' -> -1 eigenvalue (Pauli Z convention)
            return +1 if bit_char == "0" else -1

        def _expectations_from_counts(counts):
            """
            From counts over n bits, compute:
            - single expectations: <b_i> where b_i ∈ {+1,-1}
            - nearest-neighbor correlations: <b_i b_{i+1}>

            Important: Qiskit count keys are returned as strings with classical bit order.
            When using measure_all(), the rightmost character typically corresponds to qubit 0.
            We reverse the string so index i aligns with qubit i.
            """
            total = 0
            single = np.zeros(n, dtype=float)
            pair = np.zeros(max(n - 1, 0), dtype=float)

            for bitstring, c in counts.items():
                p = c / shots
                total += p

                bs = bitstring.replace(" ", "")[::-1]  # reverse so bs[i] matches qubit i
                # Safety if some backends include fewer bits (rare), pad with zeros:
                if len(bs) < n:
                    bs = bs + ("0" * (n - len(bs)))

                zvals = np.array([_bit_to_pm1(bs[i]) for i in range(n)], dtype=float)

                single += p * zvals
                if n >= 2:
                    pair += p * (zvals[:-1] * zvals[1:])

            # total should be ~1.0
            if total > 0:
                single /= total
                if n >= 2:
                    pair /= total

            return single, pair

        # ----------------------------
        # 2) Run circuits in Z/X/Y bases
        # ----------------------------
        counts_Z = _run_counts(_measured_in_basis(base_qc, "Z"))
        counts_X = _run_counts(_measured_in_basis(base_qc, "X"))
        counts_Y = _run_counts(_measured_in_basis(base_qc, "Y"))

        Z, ZZ = _expectations_from_counts(counts_Z)  # Z_i and Z_i Z_{i+1}
        X, XX = _expectations_from_counts(counts_X)  # X_i and X_i X_{i+1} (after basis map)
        Y, YY = _expectations_from_counts(counts_Y)  # Y_i and Y_i Y_{i+1}

        # ----------------------------
        # 3) Decode "primary" angles per qubit from Bloch components
        # ----------------------------
        # phi_i from atan2(Y, X) in [-pi, pi]
        phi = np.arctan2(Y, X)

        # theta_i from arccos(Z) in [0, pi]
        Zc = np.clip(Z, -1.0, 1.0)
        theta = np.arccos(Zc)

        # ----------------------------
        # 4) Make extra "psi-like" angles from correlations
        #    (Use a stable mapping: arccos(correlation) in [0, pi], then shift to [-pi, pi] if desired)
        # ----------------------------
        angles_list = []
        angles_list.extend(phi.tolist())        # n angles
        angles_list.extend((theta - np.pi/2).tolist())  # n angles centered around 0

        # Correlation-based angles
        if n >= 2:
            # Use Z-correlations primarily (like backbone coupling), plus a little XX/YY signal
            corr = 0.5 * ZZ + 0.25 * XX + 0.25 * YY
            corr = np.clip(corr, -1.0, 1.0)
            psi_like = np.arccos(corr) - np.pi/2  # center around 0
            angles_list.extend(psi_like.tolist())  # (n-1) angles

        base_angles = np.array(angles_list, dtype=float)

        # ----------------------------
        # 5) Expand / compress deterministically to self.total_angles
        #    IMPORTANT: base_angles length is O(n), but total_angles can be larger.
        #    We create additional angles via deterministic mixing (no randomness).
        # ----------------------------
        if len(base_angles) == 0:
            base_angles = np.zeros(1, dtype=float)

        if len(base_angles) >= self.total_angles:
            return base_angles[: self.total_angles]

        # Deterministic expansion using a simple sinusoidal mixing bank.
        # This keeps outputs bounded in [-pi, pi] and gives each torsion a distinct value.
        out = np.zeros(self.total_angles, dtype=float)
        out[: len(base_angles)] = base_angles

        # Fill the rest by mixing base angles in a structured way
        L = len(base_angles)
        for k in range(L, self.total_angles):
            i = k % L
            j = (k * 3 + 1) % L
            m = (k * 7 + 2) % L

            v = (
                0.60 * base_angles[i]
                + 0.30 * np.sin(base_angles[j])
                + 0.10 * np.cos(base_angles[m])
            )
            # Wrap to [-pi, pi]
            v = (v + np.pi) % (2 * np.pi) - np.pi
            out[k] = v

        return out

    def _nerf_step(self, a, b, c, bond_len, bond_angle, torsion):
        """
        Natural Extension Reference Frame (NERF)
        This is the standard math for placing atom D given atoms A, B, C.
        
        Inputs:
        - a, b, c: Coordinates of previous 3 atoms.
        - bond_len: Distance c -> d
        - bond_angle: Angle b-c-d
        - torsion: Dihedral angle a-b-c-d
        """
        bc = c - b; bc_u = bc / (np.linalg.norm(bc) + 1e-9)
        ab = b - a; n = np.cross(ab, bc_u); n_u = n / (np.linalg.norm(n) + 1e-9)
        bx_n = np.cross(n_u, bc_u)
        
        # Construct rotation matrix column-wise
        M = np.column_stack((bc_u, bx_n, n_u))
        
        theta_supp = np.pi - bond_angle
        d = np.array([bond_len * np.cos(theta_supp), bond_len * np.cos(torsion) * np.sin(theta_supp), bond_len * np.sin(torsion) * np.sin(theta_supp)])
        
        return c + (M @ d)

    def build_full_structure(self, angle_vector):
        """
        Constructs the full 3D Cartesian coordinates of the protein 
        based on the input torsion angles.
        """
        coords = []; labels = []; bonds = [] 
        
        # Map flat angle vector back to semantic names (e.g., '0_phi', '0_psi')
        angle_dict = {f"{x['res']}_{x['type']}": val for x, val in zip(self.dof_map, angle_vector)}
        
        # --- 1. INITIALIZE BACKBONE START ---
        # First 3 atoms (N, CA, C) are placed statically to establish a frame of reference.
        coords.extend([np.array([0,0,0]), np.array([1.46,0,0]), np.array([1.46 + 1.51*np.cos(1.9), 1.51*np.sin(1.9), 0])])
        labels.extend([(0, 'N', 'N'), (0, 'CA', 'C'), (0, 'C', 'C')])
        bonds.extend([(0,1), (1,2)]) 
        
        # --- 2. MAIN RESIDUE LOOP ---
        for i in range(self.n_residues):
            
            # Helper to find index of atoms in the 'coords' list
            def get_idx(r, n):
                for k in range(len(labels)-1, -1, -1): 
                    if labels[k][0] == r and labels[k][1] == n: return k
                return -1

            idx_N = get_idx(i, 'N'); idx_CA = get_idx(i, 'CA'); idx_C = get_idx(i, 'C')
            
            # --- BUILD SIDE CHAIN ---
            topo = self.SIDE_CHAIN_TOPO.get(self.sequence[i], self.SIDE_CHAIN_TOPO['DEFAULT'])
            sc_map = {} 
            for atom_def in topo:
                name, elem, b_len, b_ang, tor_def = atom_def
                
                # Determine Torsion Value
                t_val = 0.0
                if isinstance(tor_def, str) and 'chi' in tor_def:
                    t_val = angle_dict.get(f"{i}_{tor_def.replace('_branch','')}", 0.0)
                    if 'branch' in tor_def: t_val += 2.09 # Offset for branched chains (Val/Leu)
                else: t_val = tor_def # Fixed angle

                # Special Case: First Sidechain Atom (CB) connects to CA
                # Requires calculating the bisector of N-CA-C to place it correctly.
                if name == 'CB': 
                    u_nc = coords[idx_N] - coords[idx_CA]; u_cc = coords[idx_C] - coords[idx_CA]
                    n_plane = np.cross(u_nc, u_cc); n_plane /= (np.linalg.norm(n_plane)+1e-9)
                    u_mid = -(u_nc + u_cc); u_mid /= (np.linalg.norm(u_mid)+1e-9)
                    p_CB = coords[idx_CA] + (b_len * (np.cos(0.9)*u_mid + np.sin(0.9)*n_plane))
                    coords.append(p_CB); labels.append((i, name, elem)); bonds.append((idx_CA, len(coords)-1))
                    sc_map['CB'] = len(coords) - 1
                else:
                    # General NERF placement for rest of sidechain
                    p_name = 'CB'
                    # Determine Parent (Simple logic for standard topologies)
                    if name.startswith('CD'): p_name = 'CG'
                    if name.startswith('CE'): p_name = 'CD'
                    if name.startswith('CZ'): p_name = 'CE'
                    if name.startswith('NZ'): p_name = 'CE'
                    if name.startswith('OE') or name.startswith('OD'): p_name = 'CD' if name.startswith('OE') else 'CG'
                    if name.startswith('SG'): p_name = 'CB'
                    if name.startswith('CG'): p_name = 'CB'
                    if name.startswith('CD') and self.sequence[i] == 'L': p_name = 'CG'
                    
                    # New Parent Mappings for Explicit Hydrogens
                    if name.startswith('HG') and name != 'HG1': p_name = 'OG'
                    if name == 'HG1': p_name = 'OG1'
                    if name == 'HH': p_name = 'OH'
                    if name == 'HE1': p_name = 'NE1'
                    if name == 'HE2': p_name = 'NE2'

                    idx_c = sc_map.get(p_name, -1)
                    if idx_c == -1: idx_c = len(coords) - 1
                    c = coords[idx_c]
                    
                    grandp = 'CA' if p_name == 'CB' else 'CB'
                    # More specific Grandparent mapping for Hydrogens to ensure correct angle
                    if p_name == 'OG': grandp = 'CB'
                    if p_name == 'OG1': grandp = 'CB'
                    if p_name == 'OH': grandp = 'CZ'
                    if p_name == 'NE1': grandp = 'CD1'
                    if p_name == 'NE2': grandp = 'CD2' # For His

                    if grandp == 'CA': b = coords[idx_CA]; a = coords[idx_N]
                    else: b = coords[sc_map.get(grandp, idx_c-1)]; a = coords[idx_CA]
                    
                    new_pos = self._nerf_step(a, b, c, b_len, b_ang, t_val)
                    coords.append(new_pos); labels.append((i, name, elem)); bonds.append((idx_c, len(coords)-1))
                    sc_map[name] = len(coords) - 1

            # --- BUILD BACKBONE OXYGEN (Carbonyl) ---
            p_O = self._nerf_step(coords[idx_N], coords[idx_CA], coords[idx_C], 1.23, 2.1, np.pi) 
            coords.append(p_O); labels.append((i, 'O', 'O')); bonds.append((idx_C, len(coords)-1))
            
            # --- BUILD NEXT RESIDUE BACKBONE (N, CA, C) ---
            if i < self.n_residues - 1:
                psi = angle_dict.get(f"{i}_psi", -0.5)
                p_next_N = self._nerf_step(coords[idx_N], coords[idx_CA], coords[idx_C], 1.33, 2.0, psi)
                coords.append(p_next_N); labels.append((i+1, 'N', 'N')); bonds.append((idx_C, len(coords)-1))
                
                omega = np.pi # Peptide bond is planar (trans)
                p_next_CA = self._nerf_step(coords[idx_CA], coords[idx_C], p_next_N, 1.46, 2.1, omega)
                coords.append(p_next_CA); labels.append((i+1, 'CA', 'C')); bonds.append((len(coords)-2, len(coords)-1))
                
                phi = angle_dict.get(f"{i+1}_phi", -1.0)
                p_next_C = self._nerf_step(coords[idx_C], p_next_N, p_next_CA, 1.51, 1.9, phi)
                coords.append(p_next_C); labels.append((i+1, 'C', 'C')); bonds.append((len(coords)-2, len(coords)-1))

        return np.array(coords), labels, bonds

    def _initialize_topology_cache(self):
        """
        Runs structure builder once to determine static properties of atoms.
        Allows vectorization of Charges, Radii, and Types.
        """
        # Build with dummy zeros to get lists
        dummy_coords, self.static_labels, _ = self.build_full_structure(np.zeros(self.total_angles))
        n_atoms = len(dummy_coords)
        
        # 1. Map Atom Index -> Residue Index
        self.atom_to_res = np.array([x[0] for x in self.static_labels], dtype=int)
        self.atom_names = np.array([x[1] for x in self.static_labels])
        self.atom_elems = np.array([x[2] for x in self.static_labels])
        
        # 2. Pre-calculate Charges (Vectorized)
        self.q_vector = np.zeros(n_atoms)
        for k, (rid, name, elem) in enumerate(self.static_labels):
            q = self.CHARGES.get(name, 0.0)
            res_name = self.sequence[rid]
            
            # --- LOGIC PATCH: RESOLVE CHARGE NAME COLLISIONS ---
            # NE2 is ambiguous: It is an Amide (+0.5) in Gln, but an Amine (-0.4) in Neutral His.
            if res_name == 'H':
                if name == 'NE2': q = -0.4 
                if name == 'ND1': q = -0.4 
            
            # Apply Terminal Capping Logic (Neutralize ends usually)
            if rid == 0 or rid == self.n_residues - 1:
                if name in ['N', 'CA', 'C', 'O', 'OXT', 'H1', 'H2', 'H3', 'H']: q = 0.0
            self.q_vector[k] = q
        
        # 3. Pre-calculate VdW Radii (Vectorized)
        self.vdw_radii_vector = np.array([self.VDW_RADII.get(x[2], 1.7) for x in self.static_labels])
        
        # 4. Masks
        # Mask for heavy atoms (not H) - useful for Sterics
        self.mask_heavy = np.array([not x.startswith('H') for x in self.atom_names], dtype=bool)
        
        # Mask for Hydrophobic atoms (SASA)
        # NOTE: self.sequence is 1-letter codes
        hydro_res_set = set(list("AVLIMFWYPC"))  # include Tyr (Y) + Trp (W)

        self.mask_hydrophobic = np.zeros(n_atoms, dtype=bool)
        for k, (rid, name, elem) in enumerate(self.static_labels):
            aa = self.sequence[rid]

            # Only mark atoms from hydrophobic residues
            if aa not in hydro_res_set:
                continue

            # Prefer sidechain carbons (avoid backbone C/CA), and include sulfur if desired
            if name.startswith("C") and name not in ("C", "CA"):
                self.mask_hydrophobic[k] = True
            elif elem == "S":
                self.mask_hydrophobic[k] = True
                
        # Mask for Bonded/Neighbor Exclusions (i, i+1 residues)
        # We generally don't calculate VdW/Electrostatics for atoms in the same or adjacent residues
        res_diff_matrix = np.abs(self.atom_to_res[:, None] - self.atom_to_res[None, :])
        self.mask_non_bonded = (res_diff_matrix >= 2) 
        
        # Identify indices for specific calculations to avoid string parsing in loop
        self.idx_N_atoms = np.where(self.atom_names == 'N')[0]
        self.idx_O_atoms = np.where(self.atom_names == 'O')[0]
        self.idx_SG_atoms = np.where(self.atom_names == 'SG')[0]
        
        self._cache_initialized = True

    def energy_function(self, params, return_terms: bool = False):
        """
        THE CRITIC (Objective Function)
        Evaluates how "physically good" the protein structure is.
        Lower Energy = Better Fold.

        If return_terms=True, a per-term decomposition is stored in:
            self.last_energy_terms (dict)
        """
        if not self._cache_initialized: 
            self._initialize_topology_cache()

        # ==========================================
        # STAGE CONTROLLER (Guided Relaxation)
        # ==========================================
        gamma = 15.0            
        constraint_strength = 50.0 

        # Stage 3: RELAXATION
        if self.current_stage == 3:
            gamma = 2.5
            constraint_strength = 5.0

        # 1. GENERATION: Get Geometry from Quantum Parameters
        angle_vec = self._get_angles(params)
        coords, _, _ = self.build_full_structure(angle_vec)

        terms = {
            "constraint": 0.0,
            "sasa": 0.0,
            "hbond": 0.0,
            "hbond_raw": 0.0,
            "electrostatics": 0.0,
            "disulfide": 0.0,
            "vdw_repulsion": 0.0,
            "vdw_attractive": 0.0,
            "rotamer": 0.0,
            "pi_stacking": 0.0,
            "rama": 0.0,
            "geometry": 0.0,
        }
        total_energy = 0.0

        def add_term(name: str, value: float):
            nonlocal total_energy
            v = float(value)
            terms[name] += v
            total_energy += v

        # --- VECTORIZED DISTANCE MATRIX ---
        diffs = coords[:, None, :] - coords[None, :, :]
        D = np.sqrt(np.sum(diffs**2, axis=-1)) + 1e-9

        # defaults so diagnostics always exist
        neighbor_counts = np.array([0.0], dtype=float)
        burial_fractions = np.array([0.0], dtype=float)

        # 0. END-TO-END BIAS
        ca_indices = [i for i, lbl in enumerate(self.static_labels) if lbl[1] == 'CA']
        if len(ca_indices) >= 2:
            start_ca = coords[ca_indices[0]]
            end_ca = coords[ca_indices[-1]]
            dist_ends = np.linalg.norm(start_ca - end_ca)
            e_constraint = constraint_strength * (dist_ends - 5.5)**2
            add_term("constraint", e_constraint)

        # 1. IMPLICIT SOLVENT (SASA)
        if np.sum(self.mask_hydrophobic) > 0:
            hydro_dists = D[self.mask_hydrophobic, :]
            weights = 1.0 / (1.0 + np.exp(1.0 * (hydro_dists - 6.0)))
            neighbor_counts = np.sum(weights, axis=1) - 1.0
            burial_fractions = neighbor_counts / 35.0
            burial_fractions = np.clip(burial_fractions, 0.0, 1.0)
            exposed_area = 30.0 * (1.0 - burial_fractions)
            SASA_SCALE = float(os.getenv("QTF_SASA_SCALE", "0.7"))
            e_sasa = SASA_SCALE*np.sum(gamma * exposed_area)
            add_term("sasa", e_sasa)


        # 2. EXPLICIT H-BONDING
        HBOND_SCALE = float(os.getenv("QTF_HBOND_SCALE", "0.75"))

        e_hbond = 0.0
        for i_n in self.idx_N_atoms:
            res_d = self.atom_to_res[i_n]
            idx_ca = i_n + 1
            idx_prev_c = i_n - 2

            if idx_prev_c < 0 or self.atom_names[idx_prev_c] != 'C':
                pos_h = coords[i_n] + np.array([0,0,1.0]); pos_n = coords[i_n]
            else:
                p_c = coords[idx_prev_c]; p_n = coords[i_n]; p_ca = coords[idx_ca]
                v_nc = p_c - p_n; v_nc /= np.linalg.norm(v_nc)
                v_nca = p_ca - p_n; v_nca /= np.linalg.norm(v_nca)
                v_h = -(v_nc + v_nca); v_h /= np.linalg.norm(v_h)
                pos_h = p_n + v_h * 1.01; pos_n = p_n

            o_coords = coords[self.idx_O_atoms]
            o_res = self.atom_to_res[self.idx_O_atoms]
            valid_mask = np.abs(o_res - res_d) >= 2
            if not np.any(valid_mask):
                continue

            valid_o_coords = o_coords[valid_mask]
            d_ho = np.linalg.norm(valid_o_coords - pos_h, axis=1)
            close_mask = d_ho < 3.5
            if not np.any(close_mask):
                continue

            final_d_ho = d_ho[close_mask]
            final_o_coords = valid_o_coords[close_mask]

            v_hn = pos_n - pos_h; v_hn /= np.linalg.norm(v_hn)
            v_ho = final_o_coords - pos_h
            norms = np.linalg.norm(v_ho, axis=1)[:, None]
            v_ho /= norms
            angle_cos = np.dot(v_ho, v_hn)
            ang_mask = angle_cos < -0.4

            radial_term = np.exp(-(final_d_ho - 2.0)**2 / 0.5)
            angular_term = (np.abs(angle_cos) - 0.4) * 2.0
            term = -50.0 * radial_term * angular_term * ang_mask
            e_hbond += np.sum(term)

        e_hbond_scaled = HBOND_SCALE * e_hbond
        terms["hbond_raw"] = float(e_hbond)
        add_term("hbond", e_hbond_scaled)

        # 3. ELECTROSTATICS
        Q_mat = np.outer(self.q_vector, self.q_vector)
        elec_mask = np.triu(self.mask_non_bonded, k=1) & (np.abs(Q_mat) > 0.0001)
        if np.any(elec_mask):
            r_elec = D[elec_mask]
            r_elec = np.maximum(r_elec, 1.0)
            q_prod = Q_mat[elec_mask]
            add_term("electrostatics", np.sum(83.0 * q_prod / (r_elec**2)))

        # 3b. DISULFIDE
        e_disulf = 0.0
        if len(self.idx_SG_atoms) > 1:
            sg_dists = D[np.ix_(self.idx_SG_atoms, self.idx_SG_atoms)]
            sg_mask = np.triu(np.ones_like(sg_dists, dtype=bool), k=1)
            valid_dists = sg_dists[sg_mask]

            bond_strengths = np.exp(-(valid_dists - 2.05)**2 / 0.5)
            active_bonds = (valid_dists < 3.0)
            e_disulf -= np.sum(25.0 * bond_strengths * active_bonds)

            full_strengths = np.exp(-(sg_dists - 2.05)**2 / 0.5) * (sg_dists < 3.0)
            np.fill_diagonal(full_strengths, 0.0)
            saturation = np.sum(full_strengths, axis=1)
            overload = saturation - 1.0
            penalty_mask = overload > 0.1
            if np.any(penalty_mask):
                e_disulf += np.sum(40.0 * (overload[penalty_mask])**2)

        add_term("disulfide", e_disulf)

        # 4. NONBONDED VDW (repulsive + weak attractive)
        Sigma_mat = self.vdw_radii_vector[:, None] + self.vdw_radii_vector[None, :]
        heavy_mat = self.mask_heavy[:, None] & self.mask_heavy[None, :]
        vdw_mask = np.triu(self.mask_non_bonded & heavy_mat, k=1)

        # Tunable scales
        VDW_REP_SCALE = float(os.getenv("QTF_VDW_REP_SCALE", "0.1"))
        VDW_ATTR_SCALE = float(os.getenv("QTF_VDW_ATTR_SCALE", "0.1"))   # start modest; increase later only if needed

        if np.any(vdw_mask):
            r_vdw = D[vdw_mask]
            s_vdw = Sigma_mat[vdw_mask]

            # dimensionless contact ratio
            x = s_vdw / (r_vdw + 1e-9)

            # repulsive branch: only for overlaps
            collision_mask = r_vdw < s_vdw
            if np.any(collision_mask):
                x_rep = x[collision_mask]
                rep_term = x_rep ** 12
                high_e = rep_term > 50.0
                if np.any(high_e):
                    rep_term[high_e] = 50.0 + np.log(rep_term[high_e] - 49.0)
                add_term("vdw_repulsion", np.sum(VDW_REP_SCALE * rep_term))

            # attractive branch: only for near-contact, not long-range
            # window roughly from contact out to ~1.5 sigma
            near_mask = (r_vdw >= s_vdw) & (r_vdw < 1.5 * s_vdw)
            if np.any(near_mask):
                x_att = x[near_mask]
                # LJ-like attractive tail, clipped to avoid runaway collapse
                att_term = -(x_att ** 6)
                att_term = np.maximum(att_term, -2.0)
                add_term("vdw_attractive", np.sum(VDW_ATTR_SCALE * att_term))

        # LOCALS
        angle_dict = {f"{x['res']}_{x['type']}": val for x, val in zip(self.dof_map, angle_vec)}

        ROTAMER_SCALE = float(os.getenv("QTF_ROTAMER_SCALE", "1.0"))
        PI_STACK_SCALE = float(os.getenv("QTF_PI_STACK_SCALE", "1.0"))

        e_rot = self._calculate_rotamer_energy(angle_dict)
        add_term("rotamer", ROTAMER_SCALE * e_rot)

        e_pi = self._calculate_aromatic_quadrupole(coords, self.static_labels, self.atom_to_res)
        add_term("pi_stacking", PI_STACK_SCALE * e_pi)

        e_rama = 0.0
        for i in range(self.n_residues):
            if f"{i}_phi" in angle_dict and f"{i}_psi" in angle_dict:
                phi = angle_dict[f"{i}_phi"]; psi = angle_dict[f"{i}_psi"]
                aa = self.sequence[i]
                d_helix = (phi - (-1.0))**2 + (psi - (-0.8))**2
                d_sheet = (phi - (-2.3))**2 + (psi - (2.4))**2

                if aa == 'G': # Glycine is flexible
                    d_helix_L = (phi - (1.0))**2 + (psi - (0.8))**2
                    d_sheet_L = (phi - (2.3))**2 + (psi - (-2.4))**2
                    dist_best = min(d_helix, d_sheet, d_helix_L, d_sheet_L)
                    e_rama += -3.0 * np.exp(-dist_best/0.6)
                else:
                    d_forbidden = (phi - (-2.0))**2 + (psi - (1.0))**2
                    term = -3.0 * np.exp(-d_helix/0.6) - 3.0 * np.exp(-d_sheet/0.6) + 5.0 * np.exp(-d_forbidden/1.0)
                    e_rama += term
        add_term("rama", e_rama)

        e_geom, geom_subterms = self._calculate_geometry_integrity(
        coords, self.static_labels, self.atom_to_res, return_terms=True
        )
        add_term("geometry", e_geom)


        if self.tracker:
            self.tracker.log(total_energy)

        if return_terms:
            self.last_energy_terms = {
            **terms,

            # geometry diagnostics
            "geom_pro_ring": float(geom_subterms["pro_ring"]),
            "geom_chirality": float(geom_subterms["chirality"]),
            "geom_planarity": float(geom_subterms["planarity"]),

            # burial diagnostics
            "burial_mean": float(np.mean(burial_fractions)) if np.sum(self.mask_hydrophobic) > 0 else 0.0,
            "burial_min": float(np.min(burial_fractions)) if np.sum(self.mask_hydrophobic) > 0 else 0.0,
            "burial_max": float(np.max(burial_fractions)) if np.sum(self.mask_hydrophobic) > 0 else 0.0,
            "neighbor_mean": float(np.mean(neighbor_counts)) if np.sum(self.mask_hydrophobic) > 0 else 0.0,
            "neighbor_min": float(np.min(neighbor_counts)) if np.sum(self.mask_hydrophobic) > 0 else 0.0,
            "neighbor_max": float(np.max(neighbor_counts)) if np.sum(self.mask_hydrophobic) > 0 else 0.0,

            "total": float(total_energy),
        }

        return total_energy

    def _calculate_rotamer_energy(self, angle_dict):
        """
        Rotamer prior for sidechain torsions.

        chi1 is strongest and residue-aware.
        chi2+ are weaker priors that still discourage unphysical placements.
        """
        energy = 0.0

        def wrap_delta(a, b):
            return (a - b + np.pi) % (2.0 * np.pi) - np.pi

        chi_centers = [-1.0471975512, 1.0471975512, 3.1415926536]  # -60, +60, 180 deg

        for i in range(self.n_residues):
            res_name = self.sequence[i]

            # ---- chi1: strongest prior ----
            key1 = f"{i}_chi1"
            if key1 in angle_dict:
                chi = angle_dict[key1]

                if res_name in ['V', 'I', 'T']:
                    # beta-branched residues prefer trans / gauche+
                    d_trans = wrap_delta(chi, np.pi) ** 2
                    d_gplus = wrap_delta(chi, -1.0471975512) ** 2
                    energy += -3.0 * (np.exp(-d_trans / 0.5) + np.exp(-d_gplus / 0.5))

                elif res_name == 'P':
                    d_down = wrap_delta(chi, -0.5) ** 2
                    d_up = wrap_delta(chi, 0.5) ** 2
                    energy += 10.0 * min(d_down, d_up)

                elif res_name in ['W', 'F', 'Y', 'H']:
                    # aromatics: trans/gauche favored, slightly narrower
                    d_trans = wrap_delta(chi, np.pi) ** 2
                    d_gplus = wrap_delta(chi, -1.0471975512) ** 2
                    d_gminus = wrap_delta(chi, 1.0471975512) ** 2
                    energy += -2.0 * (
                        np.exp(-d_trans / 0.45)
                        + 0.8 * np.exp(-d_gplus / 0.45)
                        + 0.8 * np.exp(-d_gminus / 0.45)
                    )

                else:
                    energy += 1.0 * (1.0 + np.cos(3.0 * chi))

            # ---- chi2+ : weaker generic rotamer prior ----
            for chi_idx in (2, 3, 4, 5):
                key = f"{i}_chi{chi_idx}"
                if key not in angle_dict:
                    continue

                chi = angle_dict[key]

                # aromatic chi2 is especially important
                if chi_idx == 2 and res_name in ['W', 'F', 'Y', 'H']:
                    wells = sum(np.exp(-(wrap_delta(chi, c) ** 2) / 0.35) for c in chi_centers)
                    energy += -1.5 * wells
                else:
                    wells = sum(np.exp(-(wrap_delta(chi, c) ** 2) / 0.50) for c in chi_centers)
                    energy += -0.75 * wells

        return energy

    def _calculate_aromatic_quadrupole(self, coords, labels, atom_to_res_idx):
        """
        Calculates stacking energy between aromatic rings (Phe, Tyr, Trp).
        Uses normal vectors to detect parallel stacking.
        """
        aromatics = []
        res_indices = np.unique(atom_to_res_idx)
        for r_idx in res_indices:
            if self.sequence[r_idx] in ['F', 'Y', 'W']:
                mask = (atom_to_res_idx == r_idx)
                r_coords = coords[mask]
                r_names = self.atom_names[mask]
                
                ring_mask = np.isin(r_names, ['CG','CD1','CD2','CE1','CE2','CZ'])
                ring_atoms = r_coords[ring_mask]
                
                if len(ring_atoms) > 2:
                    centroid = np.mean(ring_atoms, axis=0)
                    v1 = ring_atoms[1] - ring_atoms[0]
                    v2 = ring_atoms[2] - ring_atoms[0]
                    normal = np.cross(v1, v2); normal /= (np.linalg.norm(normal)+1e-9)
                    aromatics.append((centroid, normal))
        
        energy_pi = 0.0
        n_aro = len(aromatics)
        if n_aro < 2: return 0.0
        
        for i in range(n_aro):
            for j in range(i+1, n_aro):
                c1, n1 = aromatics[i]; c2, n2 = aromatics[j]
                dist = np.linalg.norm(c1 - c2)
                if dist > 7.0: continue
                alignment = abs(np.dot(n1, n2))
                # T-stacking vs Parallel Stacking
                if alignment < 0.3 and 4.5 < dist < 6.0:
                     energy_pi -= 4.0 * np.exp(-(dist - 5.0)**2)
                elif alignment > 0.8 and 3.4 < dist < 4.5:
                     energy_pi -= 5.0 * np.exp(-(dist - 3.8)**2)
        return energy_pi

    def _calculate_geometry_integrity(self, coords, labels, atom_to_res_idx, return_terms=False):
        """
        Penalizes physically impossible geometries.
        Optionally returns sub-terms for debugging.
        """
        energy = 0.0

        geom_terms = {
            "pro_ring": 0.0,
            "chirality": 0.0,
            "planarity": 0.0,
        }

        res_map = {}
        for k, lbl in enumerate(labels):
            r = lbl[0]
            atom = lbl[1]
            if r not in res_map:
                res_map[r] = {}
            res_map[r][atom] = k

        for r in range(self.n_residues):
            atoms = res_map.get(r, {})
            res_name = self.sequence[r]

            # PRO ring closure penalty
            if res_name == 'P' and 'CD' in atoms and 'N' in atoms:
                d = np.linalg.norm(coords[atoms['CD']] - coords[atoms['N']])
                if abs(d - 1.47) > 0.1:
                    penalty = 50.0 * (d - 1.47) ** 2
                    energy += penalty
                    geom_terms["pro_ring"] += penalty

            # Chirality check
            if 'CA' in atoms and 'N' in atoms and 'C' in atoms and 'CB' in atoms:
                ca = coords[atoms['CA']]
                n = coords[atoms['N']]
                c = coords[atoms['C']]
                cb = coords[atoms['CB']]
                volume = np.dot(np.cross(n - ca, c - ca), cb - ca)
                if volume < 1.0:
                    penalty = 50.0 * (1.0 - volume) ** 2
                    energy += penalty
                    geom_terms["chirality"] += penalty

            # Peptide planarity
            if r < self.n_residues - 1:
                next_atoms = res_map.get(r + 1, {})
                if 'C' in atoms and 'CA' in atoms and 'N' in next_atoms and 'CA' in next_atoms:
                    idx1, idx2, idx3, idx4 = atoms['CA'], atoms['C'], next_atoms['N'], next_atoms['CA']
                    p1, p2, p3, p4 = coords[idx1], coords[idx2], coords[idx3], coords[idx4]

                    b1 = p2 - p1
                    b2 = p3 - p2
                    b3 = p4 - p3

                    n1 = np.cross(b1, b2)
                    n2 = np.cross(b2, b3)

                    n1_norm = np.linalg.norm(n1)
                    n2_norm = np.linalg.norm(n2)

                    if n1_norm > 1e-8 and n2_norm > 1e-8:
                        n1 /= n1_norm
                        n2 /= n2_norm
                        parallelism = np.dot(n1, n2)

                        next_seq = self.sequence[r + 1]
                        # For peptide planarity, we care that the planes are either parallel OR anti-parallel.
                        # Both correspond to a planar peptide geometry.
                        twist_penalty = 1.0 - abs(parallelism)

                        if twist_penalty > 0.05:
                            penalty = 20.0 * twist_penalty
                            energy += penalty
                            geom_terms["planarity"] += penalty

        if return_terms:
            return energy, geom_terms
        return energy

    def get_smart_initialization(self, n_attempts=20, seed=None):
        """
        Samples random parameters to find a good starting point (Basin Hopping).
        This avoids getting stuck in high-energy states immediately.
        
        REPRODUCIBILITY:
        Uses a hash of the sequence to seed the random number generator. 
        This ensures that every run with the same sequence starts from the same 
        initial geometry, allowing you to test energy function changes reliably.
        """
        if seed is not None:
            # Create a deterministic seed from the protein sequence
            seed = int(hashlib.sha256(self.sequence.encode('utf-8')).hexdigest(), 16) % (2**32)
        
        rng = np.random.default_rng(seed)
        
        print(f"--- SCOUTING: Checking {n_attempts} starting points ---")
        print(f" > Deterministic Seed: {seed} (Derived from Sequence)")
        
        best_params = None
        best_energy = float('inf')
        for i in range(n_attempts):
            trial_params = rng.uniform(-0.8, 0.8, self.n_params)
            e = self.energy_function(trial_params)
            if e < best_energy:
                best_energy = e
                best_params = trial_params
        print(f" > Best Start Found: Energy {best_energy:.2f}")
        return best_params

    def fold(self, max_iter=2000, initial_params=None):
        """
        MAIN EXECUTION LOOP
        Runs the 3-stage optimization curriculum.
        """
        print(f"--- STARTING QUANTUM FOLDING ---")
        self.tracker = LandscapeTracker() # Start Tracker

        # Initialization
        if initial_params is None:
            init_params = self.get_smart_initialization(n_attempts=max_iter)
        else:
            init_params = initial_params
        
        # STAGE 1: COLLAPSE
        # High Gamma (15.0) + Magnet Active
        # Purpose: Force the protein into a ball rapidly.
        print("Stage 1: Mechanical Collapse (High Force)...")
        self.tracker.mark_stage("Stage1")
        self.current_stage = 1
        res_1 = minimize(self.energy_function, init_params, method='COBYLA', options={'maxiter': max_iter, 'rhobeg': 1.0})
        print(f" > Collapse Energy: {res_1.fun:.2f}")

        # STAGE 2: REFINE
        # High Gamma (15.0) + Magnet Active + Precise Gradient Descent
        # Purpose: Fix local clashes while keeping the globular shape.
        print("Stage 2: Physics Refinement (High Force)...")
        self.tracker.mark_stage("Stage2")
        self.current_stage = 2
        res_2 = minimize(self.energy_function, res_1.x, method='SLSQP', tol=1e-6, options={'maxiter': max_iter, 'disp': True})
        print(f" > Refinement Energy: {res_2.fun:.2f}")
        
        # STAGE 3: RELAX
        # Low Gamma (2.0) + Magnet REMOVED
        # Purpose: Let the protein "breathe". H-bonds and Electrostatics take over
        # to find the native state.
        print("Stage 3: Natural Relaxation (Releasing Constraints)...")
        self.tracker.mark_stage("Stage3")
        self.current_stage = 3 
        res_3 = minimize(self.energy_function, res_2.x, method='SLSQP', tol=1e-6, options={'maxiter': max_iter, 'disp': True})
        print(f" > Relaxation Energy (Final Energy): {res_3.fun:.2f}")
        
        coords, labels, bonds = self.build_full_structure(self._get_angles(res_3.x))
        return coords, labels, bonds, self.tracker, res_3.x, res_3.fun

    def save_pdb(self, coords, labels, filename="structure.pdb", energy=0.0):
        """
        Saves the result to a PDB file viewable in PyMOL or Chimera.
        """
        with open(filename, 'w') as f:
            f.write(f"REMARK   1 ENERGY: {energy:.3f}\n")
            for k, (pos, (res_id, atom_name, elem)) in enumerate(zip(coords, labels)):
                res_name = self.sequence[res_id]
                f.write(f"ATOM  {k+1:>5}  {atom_name:<4} {res_name:>3} A{res_id+1:>4}    {pos[0]:8.3f}{pos[1]:8.3f}{pos[2]:8.3f}  1.00  0.00           {elem:>2}\n")

# ==========================================
# 4. ORCHESTRATOR: ENSEMBLE MANAGER
# ==========================================
class EnsembleFoldingManager:
    """
    Manages multiple independent folding runs (Monte Carlo / Multi-Start)
    """
    def __init__(self, folder_instance):
        self.folder = folder_instance
        self.results = [] 
    
    def prime_circuit(self, target_type='helix', seed=42):
        """
        Smart Initialization: Pre-optimizes circuit to output Secondary Structure angles.
        """
        print(f"--- PRIMING CIRCUIT FOR {target_type.upper()} ---")
        
        rng = np.random.default_rng(seed)
        
        if target_type == 'helix':
            t_phi, t_psi = np.deg2rad(-60.0), np.deg2rad(-45.0)
        elif target_type == 'sheet':
            t_phi, t_psi = np.deg2rad(-135.0), np.deg2rad(135.0)
        else:
            return rng.uniform(-0.8, 0.8, self.folder.n_params)

        targets = np.zeros(self.folder.total_angles)
        masks = np.zeros(self.folder.total_angles)
        
        for i, dof in enumerate(self.folder.dof_map):
            if dof['type'] == 'phi': targets[i] = t_phi; masks[i] = 1.0
            elif dof['type'] == 'psi': targets[i] = t_psi; masks[i] = 1.0
            
        def priming_cost(params):
            curr = self.folder._get_angles(params)
            diff = (curr - targets + np.pi) % (2 * np.pi) - np.pi
            return np.sum((diff * masks)**2)

        init_guess = rng.uniform(-0.1, 0.1, self.folder.n_params)
        res = minimize(priming_cost, init_guess, method='COBYLA', options={'maxiter': 200})
        print(f" > Priming Error: {res.fun:.4f}")
        return res.x

    def run_ensemble(self, n_runs=5, max_iter=2000, prime_strategy='mixed'):
        print(f"=== STARTING ENSEMBLE RUN ({n_runs} Trajectories) ===")
        self.results = []

        # Create a deterministic seed from the protein sequence
        # Retrieve the protein sequence from the folder object
        seed = int(hashlib.sha256(self.folder.sequence.encode('utf-8')).hexdigest(), 16) % (2**32)
        
        for i in range(n_runs):
            print(f"\n>> REPLICA {i+1}/{n_runs}")
            
            # Strategy Selection
            if prime_strategy == 'mixed':
                if i % 3 == 0: strat = 'helix'
                elif i % 3 == 1: strat = 'sheet'
                else: strat = 'random'
            else: strat = prime_strategy
                
            # Initialization
            if strat == 'random':
                start_params = self.folder.get_smart_initialization(n_attempts=50, seed=seed+i)
            else:
                start_params = self.prime_circuit(target_type=strat, seed=seed+i)
            
            # Execute Fold
            coords, _, _, tracker, final_params, final_energy = self.folder.fold(max_iter=max_iter, initial_params=start_params)
            
            print(f" >> Replica {i+1} Final Energy: {final_energy:.2f}")
            self.results.append({
                'id': i, 'seed': seed+i, 'type': strat, 'energy': final_energy,
                'coords': coords, 'params': final_params, 'tracker': tracker
            })

    def evaluate_best(self):
        if not self.results: return None, None

        sorted_results = sorted(self.results, key=lambda x: x['energy'])
        best = sorted_results[0]
        
        print(f"\n=== ENSEMBLE EVALUATION ===")
        print(f"Best Candidate: ID {best['id']} (Init: {best['type']})")
        print(f"Lowest Energy:  {best['energy']:.4f}")
        
        if len(self.results) > 1:
            StabilityAnalyzer.analyze_convergence(self.results)

        return best

    def get_ranked_results(self):
        """Return all ensemble results sorted by energy (ascending)."""
        if not self.results:
            return []
        return sorted(self.results, key=lambda x: x['energy'])

    def select_top(self, top_k=None, top_frac=None):
        """
        Select top low-energy structures.

        Parameters
        ----------
        top_k : int | None
            Keep the top_k lowest-energy structures.
        top_frac : float | None
            Keep the top fraction (0<top_frac<=1) of lowest-energy structures.
            If provided, top_frac takes precedence over top_k.

        Returns
        -------
        list[dict]
            Ranked subset of self.results.
        """
        ranked = self.get_ranked_results()
        if not ranked:
            return []
        if top_frac is not None:
            k = max(1, int(np.ceil(len(ranked) * float(top_frac))))
            return ranked[:k]
        if top_k is not None:
            k = max(1, min(int(top_k), len(ranked)))
            return ranked[:k]
        return ranked

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import urllib.request
import os

def get_ground_truth_backbone(pdb_id="5AWL"):
    url = f"https://files.rcsb.org/download/{pdb_id}.pdb"
    filename = f"{pdb_id}.pdb"
    if not os.path.exists(filename): urllib.request.urlretrieve(url, filename)
    coords_ca = []
    with open(filename, 'r') as f:
        for line in f:
            if line.startswith("ENDMDL"): break
            if line.startswith("ATOM") and "CA" in line[12:16]:
                coords_ca.append([float(line[30:38]), float(line[38:46]), float(line[46:54])])
    return np.array(coords_ca)

def calculate_physics_metrics(coords):
    end_to_end = np.linalg.norm(coords[0] - coords[-1])
    centroid = np.mean(coords, axis=0)
    rg = np.sqrt(np.mean(np.sum((coords - centroid)**2, axis=1)))
    return end_to_end, rg

if __name__ == "__main__":
    # 1. Setup Chignolin Sequence
    sequence = "YYDPETGTWY" 
    print(f"--- DIAGNOSING BACKBONE: {sequence} ---")
    
    # 2. Initialize Folder & Manager
    folder = QuantumBiophysicsFolder(sequence, force_field="amber")
    manager = EnsembleFoldingManager(folder)
    
    # 3. Run Ensemble (Using the Smart Initialization) 
    # We run 3 replicas with mixed strategies (Helix, Sheet, Random)

    manager.run_ensemble(n_runs=100, prime_strategy='random')
    
    # 4. Get Best Result
    best_result = manager.evaluate_best()
    final_coords = best_result['coords']
    tracker = best_result['tracker']
    
    # 5. Extract Backbone (CA) for Validation
    # Filter labels where atom name is 'CA'
    pred_ca = np.array([final_coords[i] for i, lbl in enumerate(folder.static_labels) if lbl[1] == 'CA'])
    true_ca = get_ground_truth_backbone("5AWL")
    
    # Truncate to match lengths (in case of differing caps)
    n = min(len(pred_ca), len(true_ca))
    pred_ca = pred_ca[:n]; true_ca = true_ca[:n]
    
    # 6. Calculate Metrics
    p_e2e, p_rg = calculate_physics_metrics(pred_ca)
    t_e2e, t_rg = calculate_physics_metrics(true_ca)
    
    print(f"\nMetric             | Predicted | Target (5AWL) | Status")
    print(f"-------------------|-----------|---------------|-------")
    print(f"End-to-End Dist    | {p_e2e:6.2f} Å | {t_e2e:6.2f} Å      | {'EXPANDED' if p_e2e > t_e2e + 5 else 'GOOD'}")
    print(f"Radius of Gyration | {p_rg:6.2f} Å | {t_rg:6.2f} Å      | {'PUFFY' if p_rg > t_rg + 2 else 'COMPACT'}")
    
    # 7. RMSD & Dual Plots
    rmsd, aligned_pred = StabilityAnalyzer.kabsch_rmsd(pred_ca, true_ca)
    print(f"\nBackbone RMSD: {rmsd:.3f} Å")
    
    fig = plt.figure(figsize=(16, 7))
    
    # PLOT 1: 3D Structure Comparison 
    ax1 = fig.add_subplot(121, projection='3d')
    ax1.plot(aligned_pred[:,0], aligned_pred[:,1], aligned_pred[:,2], '-o', c='blue', label='Prediction (Best)', lw=2)
    ax1.plot(true_ca[:,0], true_ca[:,1], true_ca[:,2], '--o', c='red', label='Target (5AWL)', alpha=0.7)
    ax1.set_title(f"3D Structure Alignment\nRMSD: {rmsd:.2f} Å", fontsize=12, fontweight='bold')
    ax1.legend()
    
    # PLOT 2: Energy Landscape of the Winner
    ax2 = fig.add_subplot(122)
    energies = np.array(tracker.history)
    energies = np.clip(energies, -1000, 2000) # Clip visuals
    ax2.plot(energies, color='#2c3e50', lw=1.5, label='Hamiltonian Energy')
    
    colors = ['#e74c3c', '#f1c40f', '#0f26f1']
    for i, (idx, name) in enumerate(tracker.stage_markers):
        if idx < len(energies):
            ax2.axvline(x=idx, color=colors[i], linestyle='--', alpha=0.8)
            ax2.text(idx + 10, max(energies)*0.9, name, color=colors[i], fontweight='bold')
            
    ax2.set_title(f"Optimization Landscape (Run #{best_result['id']})", fontsize=12, fontweight='bold')
    ax2.set_xlabel("Evaluations")
    ax2.set_ylabel("Energy")
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
# Out:
# --- DIAGNOSING BACKBONE: YYDPETGTWY ---
# --- INITIALIZING QUANTUM BIOPHYSICS FOLDER ---
# --- FORCE FIELD: AMBER ---
#
# --- ANSATZ INFO ---
# n_qubits: 6
# reps: 10
# n_params: 132
# === STARTING ENSEMBLE RUN (100 Trajectories) ===
#
# >> REPLICA 1/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 3581.52
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 697.54
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3966.9012728156545
#             Iterations: 14
#             Function evaluations: 2000
#             Gradient evaluations: 14
#  > Refinement Energy: 3966.90
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 858.9832571919374
#             Iterations: 3
#             Function evaluations: 411
#             Gradient evaluations: 3
#  > Relaxation Energy (Final Energy): 858.98
#  >> Replica 1 Final Energy: 858.98
#
# >> REPLICA 2/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 924.26
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 535.58
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5124.406722693257
#             Iterations: 201
#             Function evaluations: 28449
#             Gradient evaluations: 201
#  > Refinement Energy: 5124.41
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1121.8339169518686
#             Iterations: 79
#             Function evaluations: 11160
#             Gradient evaluations: 79
#  > Relaxation Energy (Final Energy): 1121.83
#  >> Replica 2 Final Energy: 1121.83
#
# >> REPLICA 3/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 978.92
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 594.24
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1120.2692887879625
#             Iterations: 167
#             Function evaluations: 23548
#             Gradient evaluations: 167
#  > Refinement Energy: 1120.27
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 880.2347646477444
#             Iterations: 92
#             Function evaluations: 12934
#             Gradient evaluations: 92
#  > Relaxation Energy (Final Energy): 880.23
#  >> Replica 3 Final Energy: 880.23
#
# >> REPLICA 4/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 926.15
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 505.30
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9316.991962914104
#             Iterations: 21
#             Function evaluations: 2979
#             Gradient evaluations: 21
#  > Refinement Energy: 9316.99
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 625.1440703939885
#             Iterations: 19
#             Function evaluations: 2621
#             Gradient evaluations: 19
#  > Relaxation Energy (Final Energy): 625.14
#  >> Replica 4 Final Energy: 625.14
#
# >> REPLICA 5/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 907.54
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 577.91
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7079.371700314217
#             Iterations: 216
#             Function evaluations: 30481
#             Gradient evaluations: 216
#  > Refinement Energy: 7079.37
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1203.5242379664696
#             Iterations: 196
#             Function evaluations: 27511
#             Gradient evaluations: 196
#  > Relaxation Energy (Final Energy): 1203.52
#  >> Replica 5 Final Energy: 1203.52
#
# >> REPLICA 6/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 910.77
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 536.24
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6086.419917473021
#             Iterations: 19
#             Function evaluations: 2658
#             Gradient evaluations: 19
#  > Refinement Energy: 6086.42
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 774.4107187865438
#             Iterations: 36
#             Function evaluations: 5001
#             Gradient evaluations: 36
#  > Relaxation Energy (Final Energy): 774.41
#  >> Replica 6 Final Energy: 774.41
#
# >> REPLICA 7/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 940.13
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 688.55
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7147.477953804437
#             Iterations: 272
#             Function evaluations: 38292
#             Gradient evaluations: 272
#  > Refinement Energy: 7147.48
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 864.2172243906172
#             Iterations: 155
#             Function evaluations: 21861
#             Gradient evaluations: 155
#  > Relaxation Energy (Final Energy): 864.22
#  >> Replica 7 Final Energy: 864.22
#
# >> REPLICA 8/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 900.00
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 753.56
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2100.2693180790693
#             Iterations: 16
#             Function evaluations: 2243
#             Gradient evaluations: 16
#  > Refinement Energy: 2100.27
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 639.4217514104632
#             Iterations: 5
#             Function evaluations: 681
#             Gradient evaluations: 5
#  > Relaxation Energy (Final Energy): 639.42
#  >> Replica 8 Final Energy: 639.42
#
# >> REPLICA 9/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 866.93
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 502.40
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6528.924584270383
#             Iterations: 205
#             Function evaluations: 28857
#             Gradient evaluations: 205
#  > Refinement Energy: 6528.92
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1651.980714559814
#             Iterations: 127
#             Function evaluations: 17814
#             Gradient evaluations: 127
#  > Relaxation Energy (Final Energy): 1651.98
#  >> Replica 9 Final Energy: 1651.98
#
# >> REPLICA 10/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 924.46
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 625.67
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 10089.324795725817
#             Iterations: 91
#             Function evaluations: 12751
#             Gradient evaluations: 91
#  > Refinement Energy: 10089.32
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 927.050064820438
#             Iterations: 12
#             Function evaluations: 1667
#             Gradient evaluations: 12
#  > Relaxation Energy (Final Energy): 927.05
#  >> Replica 10 Final Energy: 927.05
#
# >> REPLICA 11/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 912.04
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 582.94
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9295.975062120344
#             Iterations: 157
#             Function evaluations: 22056
#             Gradient evaluations: 157
#  > Refinement Energy: 9295.98
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1175.8581603662542
#             Iterations: 44
#             Function evaluations: 6152
#             Gradient evaluations: 44
#  > Relaxation Energy (Final Energy): 1175.86
#  >> Replica 11 Final Energy: 1175.86
#
# >> REPLICA 12/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 875.61
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 4616.07
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9654.357651076216
#             Iterations: 95
#             Function evaluations: 13379
#             Gradient evaluations: 95
#  > Refinement Energy: 9654.36
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1126.8444450318239
#             Iterations: 87
#             Function evaluations: 12142
#             Gradient evaluations: 87
#  > Relaxation Energy (Final Energy): 1126.84
#  >> Replica 12 Final Energy: 1126.84
#
# >> REPLICA 13/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 902.10
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 591.44
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5538.044603048093
#             Iterations: 62
#             Function evaluations: 8692
#             Gradient evaluations: 62
#  > Refinement Energy: 5538.04
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 876.532162202926
#             Iterations: 19
#             Function evaluations: 2637
#             Gradient evaluations: 19
#  > Relaxation Energy (Final Energy): 876.53
#  >> Replica 13 Final Energy: 876.53
#
# >> REPLICA 14/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 958.37
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 1875.61
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3419.5029798209307
#             Iterations: 49
#             Function evaluations: 6803
#             Gradient evaluations: 49
#  > Refinement Energy: 3419.50
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 901.3640273148036
#             Iterations: 7
#             Function evaluations: 981
#             Gradient evaluations: 7
#  > Relaxation Energy (Final Energy): 901.36
#  >> Replica 14 Final Energy: 901.36
#
# >> REPLICA 15/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 917.08
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 669.95
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5605.9400516324395
#             Iterations: 167
#             Function evaluations: 23470
#             Gradient evaluations: 167
#  > Refinement Energy: 5605.94
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 823.0459093655089
#             Iterations: 89
#             Function evaluations: 12476
#             Gradient evaluations: 89
#  > Relaxation Energy (Final Energy): 823.05
#  >> Replica 15 Final Energy: 823.05
#
# >> REPLICA 16/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 878.78
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 568.37
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3919.8912009585315
#             Iterations: 29
#             Function evaluations: 4040
#             Gradient evaluations: 29
#  > Refinement Energy: 3919.89
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1056.1600460001023
#             Iterations: 5
#             Function evaluations: 690
#             Gradient evaluations: 5
#  > Relaxation Energy (Final Energy): 1056.16
#  >> Replica 16 Final Energy: 1056.16
#
# >> REPLICA 17/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 895.39
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 529.90
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8161.301983552632
#             Iterations: 93
#             Function evaluations: 13015
#             Gradient evaluations: 93
#  > Refinement Energy: 8161.30
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1165.6917465480742
#             Iterations: 46
#             Function evaluations: 6394
#             Gradient evaluations: 46
#  > Relaxation Energy (Final Energy): 1165.69
#  >> Replica 17 Final Energy: 1165.69
#
# >> REPLICA 18/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 792.73
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 617.22
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5060.55882344907
#             Iterations: 7
#             Function evaluations: 981
#             Gradient evaluations: 7
#  > Refinement Energy: 5060.56
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 738.3706442536318
#             Iterations: 3
#             Function evaluations: 408
#             Gradient evaluations: 3
#  > Relaxation Energy (Final Energy): 738.37
#  >> Replica 18 Final Energy: 738.37
#
# >> REPLICA 19/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 919.41
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 662.51
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7951.922736803818
#             Iterations: 71
#             Function evaluations: 10004
#             Gradient evaluations: 71
#  > Refinement Energy: 7951.92
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 930.6290357224898
#             Iterations: 43
#             Function evaluations: 6037
#             Gradient evaluations: 43
#  > Relaxation Energy (Final Energy): 930.63
#  >> Replica 19 Final Energy: 930.63
#
# >> REPLICA 20/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 920.01
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 525.38
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3236.088633079068
#             Iterations: 244
#             Function evaluations: 34392
#             Gradient evaluations: 244
#  > Refinement Energy: 3236.09
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 733.0310711587582
#             Iterations: 114
#             Function evaluations: 16089
#             Gradient evaluations: 114
#  > Relaxation Energy (Final Energy): 733.03
#  >> Replica 20 Final Energy: 733.03
#
# >> REPLICA 21/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 909.79
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 4764.05
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5940.065710485183
#             Iterations: 97
#             Function evaluations: 13607
#             Gradient evaluations: 97
#  > Refinement Energy: 5940.07
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 839.6259178793746
#             Iterations: 10
#             Function evaluations: 1417
#             Gradient evaluations: 10
#  > Relaxation Energy (Final Energy): 839.63
#  >> Replica 21 Final Energy: 839.63
#
# >> REPLICA 22/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 898.56
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 530.99
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1598.3701540466473
#             Iterations: 232
#             Function evaluations: 32988
#             Gradient evaluations: 232
#  > Refinement Energy: 1598.37
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1106.9982340070435
#             Iterations: 70
#             Function evaluations: 9814
#             Gradient evaluations: 70
#  > Relaxation Energy (Final Energy): 1107.00
#  >> Replica 22 Final Energy: 1107.00
#
# >> REPLICA 23/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 918.66
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 592.42
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6823.880859856924
#             Iterations: 203
#             Function evaluations: 28559
#             Gradient evaluations: 203
#  > Refinement Energy: 6823.88
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1037.9102646579781
#             Iterations: 54
#             Function evaluations: 7599
#             Gradient evaluations: 54
#  > Relaxation Energy (Final Energy): 1037.91
#  >> Replica 23 Final Energy: 1037.91
#
# >> REPLICA 24/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 929.33
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 594.03
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6257.6389617583345
#             Iterations: 67
#             Function evaluations: 9375
#             Gradient evaluations: 67
#  > Refinement Energy: 6257.64
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 913.7627892704912
#             Iterations: 53
#             Function evaluations: 7374
#             Gradient evaluations: 53
#  > Relaxation Energy (Final Energy): 913.76
#  >> Replica 24 Final Energy: 913.76
#
# >> REPLICA 25/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 928.73
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 594.76
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1117.1857504747932
#             Iterations: 213
#             Function evaluations: 29997
#             Gradient evaluations: 213
#  > Refinement Energy: 1117.19
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1003.3398005340987
#             Iterations: 133
#             Function evaluations: 18622
#             Gradient evaluations: 133
#  > Relaxation Energy (Final Energy): 1003.34
#  >> Replica 25 Final Energy: 1003.34
#
# >> REPLICA 26/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 930.47
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 630.64
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5220.193129501496
#             Iterations: 150
#             Function evaluations: 21192
#             Gradient evaluations: 150
#  > Refinement Energy: 5220.19
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1252.9816603400027
#             Iterations: 82
#             Function evaluations: 11575
#             Gradient evaluations: 82
#  > Relaxation Energy (Final Energy): 1252.98
#  >> Replica 26 Final Energy: 1252.98
#
# >> REPLICA 27/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 878.76
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 631.60
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4861.957734746261
#             Iterations: 62
#             Function evaluations: 8661
#             Gradient evaluations: 62
#  > Refinement Energy: 4861.96
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1378.6057981353374
#             Iterations: 2
#             Function evaluations: 278
#             Gradient evaluations: 2
#  > Relaxation Energy (Final Energy): 1378.61
#  >> Replica 27 Final Energy: 1378.61
#
# >> REPLICA 28/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 902.35
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 1049.45
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3819.55249814599
#             Iterations: 92
#             Function evaluations: 12829
#             Gradient evaluations: 92
#  > Refinement Energy: 3819.55
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1036.5733414356496
#             Iterations: 16
#             Function evaluations: 2251
#             Gradient evaluations: 16
#  > Relaxation Energy (Final Energy): 1036.57
#  >> Replica 28 Final Energy: 1036.57
#
# >> REPLICA 29/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 921.10
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 542.52
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5512.568034727444
#             Iterations: 205
#             Function evaluations: 28993
#             Gradient evaluations: 205
#  > Refinement Energy: 5512.57
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1180.2777980572573
#             Iterations: 118
#             Function evaluations: 16547
#             Gradient evaluations: 118
#  > Relaxation Energy (Final Energy): 1180.28
#  >> Replica 29 Final Energy: 1180.28
#
# >> REPLICA 30/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 915.51
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 624.31
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3499.726929980034
#             Iterations: 120
#             Function evaluations: 16789
#             Gradient evaluations: 120
#  > Refinement Energy: 3499.73
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1071.6718506167922
#             Iterations: 61
#             Function evaluations: 8531
#             Gradient evaluations: 61
#  > Relaxation Energy (Final Energy): 1071.67
#  >> Replica 30 Final Energy: 1071.67
#
# >> REPLICA 31/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 933.56
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 609.11
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7057.517126564468
#             Iterations: 15
#             Function evaluations: 2092
#             Gradient evaluations: 15
#  > Refinement Energy: 7057.52
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1270.738063095127
#             Iterations: 5
#             Function evaluations: 686
#             Gradient evaluations: 5
#  > Relaxation Energy (Final Energy): 1270.74
#  >> Replica 31 Final Energy: 1270.74
#
# >> REPLICA 32/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 868.02
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 535.61
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4394.280786353988
#             Iterations: 178
#             Function evaluations: 25072
#             Gradient evaluations: 178
#  > Refinement Energy: 4394.28
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1096.7030196544865
#             Iterations: 103
#             Function evaluations: 14483
#             Gradient evaluations: 103
#  > Relaxation Energy (Final Energy): 1096.70
#  >> Replica 32 Final Energy: 1096.70
#
# >> REPLICA 33/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 835.29
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 594.83
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7488.6807474467005
#             Iterations: 106
#             Function evaluations: 14945
#             Gradient evaluations: 106
#  > Refinement Energy: 7488.68
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1077.1351129054729
#             Iterations: 74
#             Function evaluations: 10379
#             Gradient evaluations: 74
#  > Relaxation Energy (Final Energy): 1077.14
#  >> Replica 33 Final Energy: 1077.14
#
# >> REPLICA 34/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 916.83
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 565.38
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3488.2836599864045
#             Iterations: 246
#             Function evaluations: 34776
#             Gradient evaluations: 246
#  > Refinement Energy: 3488.28
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 689.738010416336
#             Iterations: 184
#             Function evaluations: 25882
#             Gradient evaluations: 184
#  > Relaxation Energy (Final Energy): 689.74
#  >> Replica 34 Final Energy: 689.74
#
# >> REPLICA 35/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 881.41
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 558.47
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4537.547656474029
#             Iterations: 234
#             Function evaluations: 33182
#             Gradient evaluations: 234
#  > Refinement Energy: 4537.55
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1279.0477632728944
#             Iterations: 150
#             Function evaluations: 21297
#             Gradient evaluations: 150
#  > Relaxation Energy (Final Energy): 1279.05
#  >> Replica 35 Final Energy: 1279.05
#
# >> REPLICA 36/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 910.78
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 1472.61
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8368.08330424129
#             Iterations: 230
#             Function evaluations: 32465
#             Gradient evaluations: 230
#  > Refinement Energy: 8368.08
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1057.4334019280188
#             Iterations: 201
#             Function evaluations: 28302
#             Gradient evaluations: 201
#  > Relaxation Energy (Final Energy): 1057.43
#  >> Replica 36 Final Energy: 1057.43
#
# >> REPLICA 37/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 851.78
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 1306.39
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3710.026676540945
#             Iterations: 171
#             Function evaluations: 24214
#             Gradient evaluations: 171
#  > Refinement Energy: 3710.03
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1159.1183967540892
#             Iterations: 95
#             Function evaluations: 13397
#             Gradient evaluations: 95
#  > Relaxation Energy (Final Energy): 1159.12
#  >> Replica 37 Final Energy: 1159.12
#
# >> REPLICA 38/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 889.54
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 522.10
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8182.204376763246
#             Iterations: 164
#             Function evaluations: 23120
#             Gradient evaluations: 164
#  > Refinement Energy: 8182.20
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 985.9839613471113
#             Iterations: 86
#             Function evaluations: 12112
#             Gradient evaluations: 86
#  > Relaxation Energy (Final Energy): 985.98
#  >> Replica 38 Final Energy: 985.98
#
# >> REPLICA 39/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 979.33
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 599.73
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3497.595032626686
#             Iterations: 92
#             Function evaluations: 12849
#             Gradient evaluations: 92
#  > Refinement Energy: 3497.60
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 873.6280885944054
#             Iterations: 31
#             Function evaluations: 4305
#             Gradient evaluations: 31
#  > Relaxation Energy (Final Energy): 873.63
#  >> Replica 39 Final Energy: 873.63
#
# >> REPLICA 40/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 908.19
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 668.86
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2221.254235496358
#             Iterations: 133
#             Function evaluations: 18850
#             Gradient evaluations: 133
#  > Refinement Energy: 2221.25
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1214.9667599336171
#             Iterations: 195
#             Function evaluations: 27361
#             Gradient evaluations: 195
#  > Relaxation Energy (Final Energy): 1214.97
#  >> Replica 40 Final Energy: 1214.97
#
# >> REPLICA 41/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 984.80
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 646.81
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6472.048520946183
#             Iterations: 137
#             Function evaluations: 19280
#             Gradient evaluations: 137
#  > Refinement Energy: 6472.05
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 852.2317297334444
#             Iterations: 46
#             Function evaluations: 6434
#             Gradient evaluations: 46
#  > Relaxation Energy (Final Energy): 852.23
#  >> Replica 41 Final Energy: 852.23
#
# >> REPLICA 42/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 920.45
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 520.86
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7224.674111389384
#             Iterations: 183
#             Function evaluations: 25756
#             Gradient evaluations: 183
#  > Refinement Energy: 7224.67
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 623.6163069552354
#             Iterations: 38
#             Function evaluations: 5344
#             Gradient evaluations: 38
#  > Relaxation Energy (Final Energy): 623.62
#  >> Replica 42 Final Energy: 623.62
#
# >> REPLICA 43/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 880.72
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 617.59
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4044.8202693310973
#             Iterations: 211
#             Function evaluations: 29709
#             Gradient evaluations: 211
#  > Refinement Energy: 4044.82
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1150.293290110474
#             Iterations: 69
#             Function evaluations: 9758
#             Gradient evaluations: 69
#  > Relaxation Energy (Final Energy): 1150.29
#  >> Replica 43 Final Energy: 1150.29
#
# >> REPLICA 44/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 875.59
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 740.60
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8050.909256330009
#             Iterations: 45
#             Function evaluations: 6345
#             Gradient evaluations: 45
#  > Refinement Energy: 8050.91
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 789.4273545168567
#             Iterations: 14
#             Function evaluations: 1948
#             Gradient evaluations: 14
#  > Relaxation Energy (Final Energy): 789.43
#  >> Replica 44 Final Energy: 789.43
#
# >> REPLICA 45/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 910.15
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 933.75
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1418.8984867406896
#             Iterations: 77
#             Function evaluations: 10745
#             Gradient evaluations: 77
#  > Refinement Energy: 1418.90
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1180.5738127222553
#             Iterations: 22
#             Function evaluations: 3053
#             Gradient evaluations: 22
#  > Relaxation Energy (Final Energy): 1180.57
#  >> Replica 45 Final Energy: 1180.57
#
# >> REPLICA 46/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 978.04
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 794.66
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5264.831574443165
#             Iterations: 62
#             Function evaluations: 8813
#             Gradient evaluations: 62
#  > Refinement Energy: 5264.83
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 889.1927726481555
#             Iterations: 10
#             Function evaluations: 1378
#             Gradient evaluations: 10
#  > Relaxation Energy (Final Energy): 889.19
#  >> Replica 46 Final Energy: 889.19
#
# >> REPLICA 47/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 899.26
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 692.12
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6204.445437555596
#             Iterations: 94
#             Function evaluations: 13202
#             Gradient evaluations: 94
#  > Refinement Energy: 6204.45
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1160.1513433790146
#             Iterations: 76
#             Function evaluations: 10626
#             Gradient evaluations: 76
#  > Relaxation Energy (Final Energy): 1160.15
#  >> Replica 47 Final Energy: 1160.15
#
# >> REPLICA 48/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 920.28
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 537.57
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6999.254600641532
#             Iterations: 28
#             Function evaluations: 3927
#             Gradient evaluations: 28
#  > Refinement Energy: 6999.25
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1248.4843992261647
#             Iterations: 3
#             Function evaluations: 412
#             Gradient evaluations: 3
#  > Relaxation Energy (Final Energy): 1248.48
#  >> Replica 48 Final Energy: 1248.48
#
# >> REPLICA 49/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 916.45
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 665.08
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5610.004848826192
#             Iterations: 106
#             Function evaluations: 14862
#             Gradient evaluations: 106
#  > Refinement Energy: 5610.00
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1081.0298534130382
#             Iterations: 12
#             Function evaluations: 1667
#             Gradient evaluations: 12
#  > Relaxation Energy (Final Energy): 1081.03
#  >> Replica 49 Final Energy: 1081.03
#
# >> REPLICA 50/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 904.42
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 483.55
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4153.959995196486
#             Iterations: 251
#             Function evaluations: 35563
#             Gradient evaluations: 251
#  > Refinement Energy: 4153.96
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 987.4221444656672
#             Iterations: 19
#             Function evaluations: 2674
#             Gradient evaluations: 19
#  > Relaxation Energy (Final Energy): 987.42
#  >> Replica 50 Final Energy: 987.42
#
# >> REPLICA 51/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 895.47
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 518.44
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4049.844702842324
#             Iterations: 96
#             Function evaluations: 13524
#             Gradient evaluations: 96
#  > Refinement Energy: 4049.84
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 706.5935933451144
#             Iterations: 19
#             Function evaluations: 2677
#             Gradient evaluations: 19
#  > Relaxation Energy (Final Energy): 706.59
#  >> Replica 51 Final Energy: 706.59
#
# >> REPLICA 52/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 905.36
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 507.12
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2565.164184639014
#             Iterations: 177
#             Function evaluations: 24978
#             Gradient evaluations: 177
#  > Refinement Energy: 2565.16
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 670.7202928455908
#             Iterations: 57
#             Function evaluations: 8017
#             Gradient evaluations: 57
#  > Relaxation Energy (Final Energy): 670.72
#  >> Replica 52 Final Energy: 670.72
#
# >> REPLICA 53/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 887.52
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
#  > Collapse Energy: 557.11
# Stage 2: Physics Refinement (High Force)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2571.5972026853433
#             Iterations: 162
#             Function evaluations: 22885
#             Gradient evaluations: 162
#  > Refinement Energy: 2571.60
# Stage 3: Natural Relaxation (Releasing Constraints)...
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1343.8232760119563
#             Iterations: 90
#             Function evaluations: 12616
#             Gradient evaluations: 90
#  > Relaxation Energy (Final Energy): 1343.82
#  >> Replica 53 Final Energy: 1343.82
#
# >> REPLICA 54/100
# --- SCOUTING: Checking 50 starting points ---
#  > Deterministic Seed: 313296767 (Derived from Sequence)
#  > Best Start Found: Energy 938.16
# --- STARTING QUANTUM FOLDING ---
# Stage 1: Mechanical Collapse (High Force)...
# ...
#     745 total_energy = 0.0
#
# Cell In[12], line 460, in QuantumBiophysicsFolder._get_angles(self, params, backend, shots)
#     456 # ----------------------------
#     457 # 2) Run circuits in Z/X/Y bases
#     458 # ----------------------------
#     459 counts_Z = _run_counts(_measured_in_basis(base_qc, "Z"))
# --> 460 counts_X = _run_counts(_measured_in_basis(base_qc, "X"))
#     461 counts_Y = _run_counts(_measured_in_basis(base_qc, "Y"))
#     463 Z, ZZ = _expectations_from_counts(counts_Z)  # Z_i and Z_i Z_{i+1}
#
# Cell In[12], line 410, in QuantumBiophysicsFolder._get_angles.<locals>._run_counts(qc)
#     409 def _run_counts(qc):
# --> 410     tqc = transpile(qc, backend)
#     411     job = backend.run(tqc, shots=shots)
#     412     result = job.result()
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/compiler/transpiler.py:428, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     411     warnings.filterwarnings(
#     412         "ignore",
#     413         category=DeprecationWarning,
#     414         message=".*``instruction_durations`` is deprecated as of Qiskit 1.3.*",
#     415         module="qiskit",
#     416     )
#     417     warnings.filterwarnings(
#     418         "ignore",
#     419         category=DeprecationWarning,
#     420         message=".*``backend_properties`` is deprecated as of Qiskit 1.3.*",
#     421         module="qiskit",
#     422     )
#     423     pm = generate_preset_pass_manager(
#     424         optimization_level,
#     425         target=target,
#     426         backend=backend,
#     427         basis_gates=basis_gates,
# --> 428         coupling_map=coupling_map,
#     429         instruction_durations=instruction_durations,
#     430         backend_properties=backend_properties,
#     431         timing_constraints=timing_constraints,
#     432         inst_map=inst_map,
#     433         initial_layout=initial_layout,
#     434         layout_method=layout_method,
#     435         routing_method=routing_method,
#     436         translation_method=translation_method,
#     437         scheduling_method=scheduling_method,
#     438         approximation_degree=approximation_degree,
#     439         seed_transpiler=seed_transpiler,
#     440         unitary_synthesis_method=unitary_synthesis_method,
#     441         unitary_synthesis_plugin_config=unitary_synthesis_plugin_config,
#     442         hls_config=hls_config,
#     443         init_method=init_method,
#     444         optimization_method=optimization_method,
#     445         dt=dt,
#     446         qubits_initially_zero=qubits_initially_zero,
#     447     )
#     449 out_circuits = pm.run(circuits, callback=callback, num_processes=num_processes)
#     451 for name, circ in zip(output_name, out_circuits):
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:534, in run(self, circuits, output_name, callback)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:553, in wrapper(*meth_args, **meth_kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:291, in run(self, circuits, output_name, callback)
#     260 class StagedPassManager(PassManager):
#     261     """A pass manager pipeline built from individual stages.
#     262
#     263     This class enables building a compilation pipeline out of fixed stages.
#     264     Each ``StagedPassManager`` defines a list of stages which are executed in
#     265     a fixed order, and each stage is defined as a standalone :class:`~.PassManager`
#     266     instance. There are also ``pre_`` and ``post_`` stages for each defined stage.
#     267     This enables easily composing and replacing different stages and also adding
#     268     hook points to enable programmatic modifications to a pipeline. When using a staged
#     269     pass manager you are not able to modify the individual passes and are only able
#     270     to modify stages.
#     271
#     272     By default, instances of ``StagedPassManager`` define a typical full compilation
#     273     pipeline from an abstract virtual circuit to one that is optimized and
#     274     capable of running on the specified backend. The default pre-defined stages are:
#     275
#     276     #. ``init`` - Initial passes to run before embedding the circuit to the backend.
#     277     #. ``layout`` - Maps the virtual qubits in the circuit to the physical qubits on
#     278        the backend.
#     279     #. ``routing`` - Inserts gates as needed to move the qubit states around until
#     280        the circuit can be run with the chosen layout on the backend's coupling map.
#     281     #. ``translation`` - Translates the gates in the circuit to the target backend's
#     282        basis gate set.
#     283     #. ``optimization`` - Optimizes the circuit to reduce the cost of executing it.
#     284        These passes will typically run in a loop until a convergence criteria is met.
#     285        For example, the convergence criteria might be that the circuit depth does not
#     286        decrease in successive iterations.
#     287     #. ``scheduling`` - Hardware-aware passes that schedule the operations in the
#     288        circuit.
#     289
#     290     .. note::
# --> 291
#     292         For backwards compatibility the relative positioning of these default
#     293         stages will remain stable moving forward. However, new stages may be
#     294         added to the default stage list in between current stages. For example,
#     295         in a future release a new phase, something like ``logical_optimization``, could be added
#     296         immediately after the existing ``init`` stage in the default stage list.
#     297         This would preserve compatibility for pre-existing ``StagedPassManager``
#     298         users as the relative positions of the stage are preserved so the behavior
#     299         will not change between releases.
#     300
#     301     These stages will be executed in order and any stage set to ``None`` will be skipped.
#     302     If a stage is provided multiple times (i.e. at diferent relative positions), the
#     303     associated passes, including pre and post, will run once per declaration.
#     304     If a :class:`~qiskit.transpiler.PassManager` input is being used for more than 1 stage here
#     305     (for example in the case of a :class:`~.Pass` that covers both Layout and Routing) you will
#     306     want to set that to the earliest stage in sequence that it covers.
#     307     """
#     309     invalid_stage_regex = re.compile(
#     310         r"\s|\+|\-|\*|\/|\\|\%|\<|\>|\@|\!|\~|\^|\&|\:|\[|\]|\{|\}|\(|\)"
#     311     )
#     313     def __init__(self, stages: Iterable[str] | None = None, **kwargs) -> None:
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/passmanager/passmanager.py:222, in run(self, in_programs, callback, **kwargs)
#     175 def run(
#     176     self,
#     177     in_programs: Any | list[Any],
#    (...)
#     182     **kwargs,
#     183 ) -> Any:
#     184     """Run all the passes on the specified ``in_programs``.
#     185
#     186     Args:
#     187         in_programs: Input programs to transform via all the registered passes.
#     188             A single input object cannot be a Python builtin list object.
#     189             A list object is considered as multiple input objects to optimize.
#     190         callback: A callback function that will be called after each pass execution. The
#     191             function will be called with 4 keyword arguments::
#     192
#     193                 task (GenericPass): the pass being run
#     194                 passmanager_ir (Any): depending on pass manager subclass
#     195                 property_set (PropertySet): the property set
#     196                 running_time (float): the time to execute the pass
#     197                 count (int): the index for the pass execution
#     198
#     199             The exact arguments pass expose the internals of the pass
#     200             manager and are subject to change as the pass manager internals
#     201             change. If you intend to reuse a callback function over
#     202             multiple releases be sure to check that the arguments being
#     203             passed are the same.
#     204
#     205             To use the callback feature you define a function that will
#     206             take in kwargs dict and access the variables. For example::
#     207
#     208                 def callback_func(**kwargs):
#     209                     task = kwargs['task']
#     210                     passmanager_ir = kwargs['passmanager_ir']
#     211                     property_set = kwargs['property_set']
#     212                     running_time = kwargs['running_time']
#     213                     count = kwargs['count']
#     214                     ...
#     215         num_processes: The maximum number of parallel processes to launch if parallel
#     216             execution is enabled. This argument overrides ``num_processes`` in the user
#     217             configuration file, and the ``QISKIT_NUM_PROCS`` environment variable. If set
#     218             to ``None`` the system default or local user configuration will be used.
#     219         property_set: Currently a key that will be interpreted as all other arbitrary
#     220             ``kwargs``.  In Qiskit 2.0, this will instead seed the :class:`.PropertySet` of the
#     221             compilation (but does not do so in this version).
# --> 222         kwargs: Arbitrary arguments passed to the compiler frontend and backend.
#     223
#     224     Returns:
#     225         The transformed program(s).
#     226     """
#     227     if property_set is not _MISSING:
#     228         warnings.warn(
#     229             "From Qiskit 2.0, 'property_set' will be a reserved keyword argument of"
#     230             " 'BasePassManager.run', and not passed on to the conversion functions."
#    (...)
#     234             stacklevel=2,
#     235         )
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/passmanager/passmanager.py:280, in _run_workflow(program, pass_manager, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:68, in _passmanager_frontend(self, input_program, **kwargs)
#      57 def _passmanager_frontend(
#      58     self,
#      59     input_program: QuantumCircuit,
#      60     **kwargs,
#      61 ) -> DAGCircuit:
#      62     return circuit_to_dag(input_program, copy_operations=True)
#      64 def _passmanager_backend(
#      65     self,
#      66     passmanager_ir: DAGCircuit,
#      67     in_program: QuantumCircuit,
# ---> 68     **kwargs,
#      69 ) -> QuantumCircuit:
#      70     out_program = dag_to_circuit(passmanager_ir, copy_operations=False)
#      72     self._finalize_layouts(passmanager_ir)
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/converters/circuit_to_dag.py:91, in circuit_to_dag(circuit, copy_operations, qubit_order, clbit_order)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/site-packages/qiskit/circuit/instruction.py:504, in __deepcopy__(self, memo)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:211, in _deepcopy_tuple(x, memo, deepcopy)
#     210 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 211     y = [deepcopy(a, memo) for a in x]
#     212     # We're not going to put the tuple in the memo, but it's still important we
#     213     # check for it, in case the tuple contains recursive mutable structures.
#     214     try:
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:211, in <listcomp>(.0)
#     210 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 211     y = [deepcopy(a, memo) for a in x]
#     212     # We're not going to put the tuple in the memo, but it's still important we
#     213     # check for it, in case the tuple contains recursive mutable structures.
#     214     try:
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/miniforge3/envs/QTF-env/lib/python3.10/copy.py:138, in deepcopy(x, memo, _nil)
#     135     memo = {}
#     137 d = id(x)
# --> 138 y = memo.get(d, _nil)
#     139 if y is not _nil:
#     140     return y
#
# KeyboardInterrupt:
